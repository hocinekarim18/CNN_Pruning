# %% [markdown]
# ## Bibiliothèque

# %%
import numpy as np
import tensorflow as tf;
import matplotlib.pyplot as plt
from resnet import resnet_v2
import time
# %matplotlib inline
seed = tf.random.set_seed(42)

# %%
def plot_hist(figname):
    plt.figure(figsize=(15,7))
    plt.subplot(121)
    plt.plot(accuracy, label = "train accuracy")
    plt.plot(val_accuracy, label = "validation accuracy")
    plt.title("Accuracy")
    plt.grid()
    plt.legend()

    plt.subplot(122)
    plt.plot(l, label = "train loss")
    plt.plot(val_l, label = "validation loss")
    plt.title("Loss")
    plt.grid()
    plt.legend()

    plt.savefig(figname)
    plt.show()
    
def inference_time():
    scratch = []
    pruned = []
    for i in range(10):
        t1 = time.time()
        pred1 = scratch_model(x_test)
        t2 = time.time()
        scratch.append(t2-t1)

        # Pruned model
        t3 = time.time()
        pred2 = P.model(x_test)
        t4 = time.time()
        pruned.append(t4-t3)

    # display
    print("Scratch inference time : ", np.mean(scratch), " s")
    print("Pruned inference time : ", np.mean(pruned), " s")
    return np.mean(pruned)


def count_parameters(model):
    somme = 0
    for l in model.trainable_variables:
        somme += np.count_nonzero(l)
    return somme



def scratch_hist():   
    loss = dico["scratch_hist"][0].history["loss"]
    val_loss = dico["scratch_hist"][0].history["val_loss"]
    accuracy = dico["scratch_hist"][0].history["sparse_categorical_accuracy"]
    val_accuracy =  dico["scratch_hist"][0].history["val_sparse_categorical_accuracy"]

    for i in range(len( dico["scratch_hist"])):
        if i !=0:
            loss = np.append(loss, dico["scratch_hist"][i].history["loss"])
            val_loss = np.append(val_loss, dico["scratch_hist"][i].history["val_loss"])
            accuracy = np.append(accuracy, dico["scratch_hist"][i].history["sparse_categorical_accuracy"])
            val_accuracy =  np.append(val_accuracy, dico["scratch_hist"][i].history["val_sparse_categorical_accuracy"])

    dico["scratch_hist"] = (accuracy, val_accuracy, loss, val_loss)

# %% [markdown]
# ## Loading Mnist Dataset

# %%
def padding_mnist(x_train, x_test, pad=1):
    
    x = np.zeros((x_train.shape[0],x_train.shape[1]+2*pad, x_train.shape[2]+2*pad ))
    xt = np.zeros((x_test.shape[0],x_test.shape[1]+2*pad, x_test.shape[2]+2*pad ))
    
    for i in range(x_train.shape[0]):
        x[i] = np.pad(x_train[i], pad)
        if i < x_test.shape[0]:
            xt[i] = np.pad(x_test[i], pad)
            
    return (x, xt)
            
        

print("================ Data Loading ================")
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# Data shapes
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print("")


#padding
x_train = np.pad(x_train[:], 2)
x_test = np.pad(x_test[:], 2)

# Data shapes
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print("")

x_train = np.reshape(x_train, (-1,32,32,1))
x_test = np.reshape(x_test, (-1,32,32,1))

# Data shapes
print("x_train shape:", x_train.shape)
print("x_test shape:", x_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
print("")
# Out:
# ================ Data Loading ================
# x_train shape: (60000, 28, 28)
# x_test shape: (10000, 28, 28)
# y_train shape: (60000,)
# y_test shape: (10000,)
#
# x_train shape: (60004, 32, 32)
# x_test shape: (10004, 32, 32)
# y_train shape: (60000,)
# y_test shape: (10000,)
#
# x_train shape: (60004, 32, 32, 1)
# x_test shape: (10004, 32, 32, 1)
# y_train shape: (60000,)
# y_test shape: (10000,)

# %% [markdown]
# ## Building Lenet5 model

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(filters=6, kernel_size=(5, 5), activation='relu', input_shape=(32,32,1)),
    tf.keras.layers.AveragePooling2D(pool_size=(2,2), strides=2, padding="valid"),
    tf.keras.layers.Conv2D(filters=16, kernel_size=(5, 5), activation='relu'),
    tf.keras.layers.AveragePooling2D(pool_size=(2,2), strides=2, padding="valid"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=120, activation='relu'),
    tf.keras.layers.Dense(units=84, activation='relu'),
    tf.keras.layers.Dense(units=10, activation="softmax")

]);

model.summary();
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 24, 24, 6)         156
#
#  average_pooling2d_2 (Averag  (None, 12, 12, 6)        0
#  ePooling2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 16)          2416
#
#  average_pooling2d_3 (Averag  (None, 4, 4, 16)         0
#  ePooling2D)
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 120)               30840
#
#  dense_4 (Dense)             (None, 84)                10164
#
#  dense_5 (Dense)             (None, 10)                850
#
# =================================================================
# Total params: 44,426
# Trainable params: 44,426
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Scratch Training

# %%
# disctionnaire pour enregistrer les infos pertinentes
dico = {}
scratch_model = tf.keras.models.clone_model(model)

# %%
BATCH_SIZE = 32
EPOCHS = 100
lr = 1

# %%
dico["scratch_hist"] = []
for epoch in [75, 15, 10 ]:
    lr /= 10
    scratch_model.compile(
            optimizer = tf.keras.optimizers.SGD(learning_rate=lr),
            metrics = [tf.keras.metrics.SparseCategoricalAccuracy()],
            loss= tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
            )

        # Train and evaluate on data.
    hist = scratch_model.fit(x_train, y_train, 
          batch_size = BATCH_SIZE,
          epochs= epoch,
          steps_per_epoch = len(x_train)/BATCH_SIZE,
          validation_data =(x_test, y_test),
          workers =40,
          use_multiprocessing= True,
          )

    scratch_model.evaluate(x_test, y_test)
    dico["scratch_hist"].append(hist)
scratch_hist()
# Out:
# Epoch 1/75
# 1875/1875 [==============================] - 15s 8ms/step - loss: 0.2368 - sparse_categorical_accuracy: 0.9261 - val_loss: 0.0705 - val_sparse_categorical_accuracy: 0.9780
# Epoch 2/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0751 - sparse_categorical_accuracy: 0.9770 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9813
# Epoch 3/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0530 - sparse_categorical_accuracy: 0.9836 - val_loss: 0.0428 - val_sparse_categorical_accuracy: 0.9868
# Epoch 4/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0416 - sparse_categorical_accuracy: 0.9869 - val_loss: 0.0464 - val_sparse_categorical_accuracy: 0.9849
# Epoch 5/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0358 - sparse_categorical_accuracy: 0.9889 - val_loss: 0.0428 - val_sparse_categorical_accuracy: 0.9856
# Epoch 6/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0285 - sparse_categorical_accuracy: 0.9911 - val_loss: 0.0397 - val_sparse_categorical_accuracy: 0.9873
# Epoch 7/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0259 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9832
# Epoch 8/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0224 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.0468 - val_sparse_categorical_accuracy: 0.9865
# Epoch 9/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0192 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.0380 - val_sparse_categorical_accuracy: 0.9883
# Epoch 10/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0169 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.0314 - val_sparse_categorical_accuracy: 0.9904
# Epoch 11/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0151 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.0456 - val_sparse_categorical_accuracy: 0.9858
# Epoch 12/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9958 - val_loss: 0.0368 - val_sparse_categorical_accuracy: 0.9893
# Epoch 13/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0118 - sparse_categorical_accuracy: 0.9962 - val_loss: 0.0412 - val_sparse_categorical_accuracy: 0.9890
# Epoch 14/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0098 - sparse_categorical_accuracy: 0.9970 - val_loss: 0.0408 - val_sparse_categorical_accuracy: 0.9895
# Epoch 15/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0094 - sparse_categorical_accuracy: 0.9971 - val_loss: 0.0389 - val_sparse_categorical_accuracy: 0.9891
# Epoch 16/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9972 - val_loss: 0.0422 - val_sparse_categorical_accuracy: 0.9894
# Epoch 17/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0074 - sparse_categorical_accuracy: 0.9976 - val_loss: 0.0470 - val_sparse_categorical_accuracy: 0.9892
# Epoch 18/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0066 - sparse_categorical_accuracy: 0.9981 - val_loss: 0.0449 - val_sparse_categorical_accuracy: 0.9896
# Epoch 19/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0077 - sparse_categorical_accuracy: 0.9974 - val_loss: 0.0453 - val_sparse_categorical_accuracy: 0.9896
# Epoch 20/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0539 - val_sparse_categorical_accuracy: 0.9869
# Epoch 21/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9985 - val_loss: 0.0490 - val_sparse_categorical_accuracy: 0.9887
# Epoch 22/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0058 - sparse_categorical_accuracy: 0.9982 - val_loss: 0.0548 - val_sparse_categorical_accuracy: 0.9879
# Epoch 23/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0051 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9889
# Epoch 24/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0050 - sparse_categorical_accuracy: 0.9984 - val_loss: 0.0431 - val_sparse_categorical_accuracy: 0.9898
# Epoch 25/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0028 - sparse_categorical_accuracy: 0.9992 - val_loss: 0.0464 - val_sparse_categorical_accuracy: 0.9906
# Epoch 26/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0027 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0435 - val_sparse_categorical_accuracy: 0.9898
# Epoch 27/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0035 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0529 - val_sparse_categorical_accuracy: 0.9887
# Epoch 28/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0040 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0401 - val_sparse_categorical_accuracy: 0.9914
# Epoch 29/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0017 - sparse_categorical_accuracy: 0.9995 - val_loss: 0.0483 - val_sparse_categorical_accuracy: 0.9896
# Epoch 30/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0605 - val_sparse_categorical_accuracy: 0.9884
# Epoch 31/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0043 - sparse_categorical_accuracy: 0.9986 - val_loss: 0.0572 - val_sparse_categorical_accuracy: 0.9882
# Epoch 32/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0057 - sparse_categorical_accuracy: 0.9980 - val_loss: 0.0398 - val_sparse_categorical_accuracy: 0.9912
# Epoch 33/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0037 - sparse_categorical_accuracy: 0.9990 - val_loss: 0.0473 - val_sparse_categorical_accuracy: 0.9903
# Epoch 34/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0048 - sparse_categorical_accuracy: 0.9983 - val_loss: 0.0464 - val_sparse_categorical_accuracy: 0.9903
# Epoch 35/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0038 - sparse_categorical_accuracy: 0.9988 - val_loss: 0.0501 - val_sparse_categorical_accuracy: 0.9905
# Epoch 36/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0041 - sparse_categorical_accuracy: 0.9987 - val_loss: 0.0513 - val_sparse_categorical_accuracy: 0.9899
# Epoch 37/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 0.0029 - sparse_categorical_accuracy: 0.9991 - val_loss: 0.0428 - val_sparse_categorical_accuracy: 0.9905
# Epoch 38/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 5.9581e-04 - sparse_categorical_accuracy: 0.9999 - val_loss: 0.0452 - val_sparse_categorical_accuracy: 0.9910
# Epoch 39/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.0292e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0444 - val_sparse_categorical_accuracy: 0.9915
# Epoch 40/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.2083e-04 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0446 - val_sparse_categorical_accuracy: 0.9916
# Epoch 41/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 9.3746e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0454 - val_sparse_categorical_accuracy: 0.9918
# Epoch 42/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 5.8832e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0461 - val_sparse_categorical_accuracy: 0.9917
# Epoch 43/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 5.2933e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0467 - val_sparse_categorical_accuracy: 0.9917
# Epoch 44/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 4.4988e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0474 - val_sparse_categorical_accuracy: 0.9918
# Epoch 45/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 3.9112e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0479 - val_sparse_categorical_accuracy: 0.9918
# Epoch 46/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 3.6365e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0487 - val_sparse_categorical_accuracy: 0.9916
# Epoch 47/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 3.1080e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0489 - val_sparse_categorical_accuracy: 0.9919
# Epoch 48/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 3.0868e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0496 - val_sparse_categorical_accuracy: 0.9918
# Epoch 49/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.7900e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0497 - val_sparse_categorical_accuracy: 0.9918
# Epoch 50/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.5855e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0501 - val_sparse_categorical_accuracy: 0.9919
# Epoch 51/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.4594e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0506 - val_sparse_categorical_accuracy: 0.9919
# Epoch 52/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.2845e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0508 - val_sparse_categorical_accuracy: 0.9918
# Epoch 53/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 2.1490e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0513 - val_sparse_categorical_accuracy: 0.9917
# Epoch 54/75
# 1875/1875 [==============================] - 13s 7ms/step - loss: 2.0113e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0516 - val_sparse_categorical_accuracy: 0.9917
# Epoch 55/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.9355e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0519 - val_sparse_categorical_accuracy: 0.9917
# Epoch 56/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.8419e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0521 - val_sparse_categorical_accuracy: 0.9918
# Epoch 57/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.7573e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0523 - val_sparse_categorical_accuracy: 0.9917
# Epoch 58/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.6767e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0527 - val_sparse_categorical_accuracy: 0.9917
# Epoch 59/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.5747e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0529 - val_sparse_categorical_accuracy: 0.9917
# Epoch 60/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.5392e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0531 - val_sparse_categorical_accuracy: 0.9917
# Epoch 61/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.4707e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0534 - val_sparse_categorical_accuracy: 0.9918
# Epoch 62/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.3959e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0536 - val_sparse_categorical_accuracy: 0.9918
# Epoch 63/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.3609e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0538 - val_sparse_categorical_accuracy: 0.9918
# Epoch 64/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.2983e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0540 - val_sparse_categorical_accuracy: 0.9918
# Epoch 65/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.2321e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0542 - val_sparse_categorical_accuracy: 0.9919
# Epoch 66/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.2489e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0543 - val_sparse_categorical_accuracy: 0.9919
# Epoch 67/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.1930e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0545 - val_sparse_categorical_accuracy: 0.9919
# Epoch 68/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.1545e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0546 - val_sparse_categorical_accuracy: 0.9919
# Epoch 69/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.1162e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0548 - val_sparse_categorical_accuracy: 0.9919
# Epoch 70/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.0856e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0551 - val_sparse_categorical_accuracy: 0.9919
# Epoch 71/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.0422e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0552 - val_sparse_categorical_accuracy: 0.9919
# Epoch 72/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.0304e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0554 - val_sparse_categorical_accuracy: 0.9919
# Epoch 73/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 1.0041e-05 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0555 - val_sparse_categorical_accuracy: 0.9919
# Epoch 74/75
# 1875/1875 [==============================] - 14s 7ms/step - loss: 9.6454e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0557 - val_sparse_categorical_accuracy: 0.9919
# Epoch 75/75
# 1875/1875 [==============================] - 13s 7ms/step - loss: 9.5067e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0559 - sparse_categorical_accuracy: 0.9919
# Epoch 1/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.9382e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 2/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.9139e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 3/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.8900e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 4/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.8672e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 5/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.8450e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 6/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.8223e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0559 - val_sparse_categorical_accuracy: 0.9919
# Epoch 7/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.7970e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 8/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.7812e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 9/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.7612e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 10/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.7401e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 11/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.7196e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 12/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.6971e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 13/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.6783e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0560 - val_sparse_categorical_accuracy: 0.9919
# Epoch 14/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.6580e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 15/15
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.6385e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0561 - sparse_categorical_accuracy: 0.9919
# Epoch 1/10
# 1875/1875 [==============================] - 13s 7ms/step - loss: 8.5916e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 2/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5895e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 3/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5874e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 4/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5854e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 5/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5833e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 6/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5813e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 7/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5790e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 8/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5773e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 9/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5756e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# Epoch 10/10
# 1875/1875 [==============================] - 14s 7ms/step - loss: 8.5735e-06 - sparse_categorical_accuracy: 1.0000 - val_loss: 0.0561 - val_sparse_categorical_accuracy: 0.9919
# 313/313 [==============================] - 1s 4ms/step - loss: 0.0561 - sparse_categorical_accuracy: 0.9919

# %% [markdown]
# ## Pruning class

# %%
class Pruning:
    def __init__(self, model, pruning_factor = 0.5):
        
        # attributs liés au model
        self.model = model
        self.pruning_factor = pruning_factor
    
    # Tensorflow utils setting
    def compile(self,optimizer, loss_fn, metric):
        self.optimizer = optimizer
        self.loss_fn = loss_fn
        self.acc_metric = metric
    
    # Pruning Function
    def pruning(self, P_factor = 0.5):
        if P_factor >=1 or P_factor <= 0:
            raise ValueError ("Pruning factor value Error : Pruning factor value should be ]0 ;1[")
        for layer in self.model.layers:
            if "conv" in layer.name:
                
                # Récuper les kernels
                w = layer.get_weights()[0]
                b = layer.get_weights()[1]
                
                # Calcul du filtre contenant la median
                tab = []
                for i in range(w.shape[-1]):
                    somme = 0
                    for j in range(w.shape[-1]):
                        if i !=j:
                            somme += np.linalg.norm(w[:,:,:,i] - w[:,:,:,j])
                    tab.append(somme)
                    
                # calcul du nombre de filtrer a annuler selon le facteur de pruning
                nb_pruned_filters = int(w.shape[-1]*P_factor)
                
                for i in range(nb_pruned_filters):
                    # récupérer l'indice du minimum
                    ind_min = np.argmin(tab)
                    
                    #anuuler le filtre qui minimise la formule précedente
                    w[:, :, :, ind_min] = np.zeros(w[:, :, :, ind_min].shape)
                    
                    # astuce pour déplacer le minimum lorsque il faut annuler plusieurs filtres
                    tab[ind_min] = 1e10
                
                layer.set_weights([w, b])


                
                
    #Training algorithm
    def train(self,x_train, y_train, val_data, val_labels, epochs = 100, batch_size= 32):
        self.epochs = epochs
        self.batch_size = batch_size
        
        # training history storage
        accur = []
        L = []
        
        # validation history storage
        v_accur = []
        v_loss = []

        if x_train.shape[0] % batch_size == 0:
            nb_train_steps = x_train.shape[0] // batch_size
        else:
            nb_train_steps = (x_train.shape[0] // batch_size) + 1
        # Training Loop
        for epoch in range(epochs):
            print(f"Epoch ({epoch +1 }/{epochs})")
            for i in range(nb_train_steps):
                # Batching data
                x = x_train[i*batch_size:(i+1)*batch_size]
                y = y_train[i*batch_size:(i+1)*batch_size]
                
                x = tf.constant(x)
                y = tf.constant(y)
                
                with tf.GradientTape() as tape:
                    # Forward pass
                    predictions = self.model(x, training = True)
                    # calcul de la loss
                    loss = self.loss_fn(y, predictions)
                    
                # Calcul du gradient
                grads = tape.gradient(loss, self.model.trainable_weights)
                
                # Decente de gradient
                self.optimizer.apply_gradients(zip(grads, self.model.trainable_weights))
                
                #Pruning step
                self.pruning(P_factor = self.pruning_factor)
                
                # Update training metric.
                self.acc_metric.update_state(y, predictions)
                train_acc = self.acc_metric.result()
                
                print("Accuracy: {:.4f} ; loss: {:.4f}".format(float(train_acc),  loss), end='\r')
            print("\nValidation Step :")
            
            # Validation step
            val_accur, val_loss = self.test(val_data, val_labels)
                
            accur.append(float(train_acc))
            L.append(loss)
            
            v_accur.append(val_accur)
            v_loss.append(val_loss)
            print("")
        return (accur, L, v_accur, v_loss)  

    
    # Test Step 
    def test(self,data, labels):
        accur = []
        l = []
        if data.shape[0] % self.batch_size == 0:
            nb_test_steps = data.shape[0] // self.batch_size
        else:
            nb_test_steps = (data.shape[0] // self.batch_size) + 1
            
        for i in range(nb_test_steps):
            # Batching data
            x = data[i*self.batch_size:(i+1)*self.batch_size]
            y = labels[i*self.batch_size:(i+1)*self.batch_size]
            
            x = tf.constant(x)
            y = tf.constant(y)
            
            # Forward pass
            predictions = self.model(x)

            # calcul de la loss
            loss = self.loss_fn(y, predictions)
            # calcul de l'accuracy
            self.acc_metric.update_state(y, predictions)
            test_acc = self.acc_metric.result()
            print("Accuracy: {:.4f} ; loss: {:.4f}".format(float(test_acc),  loss), end='\r')
                
            accur.append(float(test_acc))
            l.append(float(loss))
        print("")        
        print("Accuracy Moy : {:.4f} ; loss Moy: {:.4f}" .format(np.mean(accur), np.mean(l) ))
        
        return (np.mean(accur), np.mean(l))

# %% [markdown]
# ## Training Network

# %%
for p in [0.5, 0.6, 0.7, 0.8, 0.9]:
    accuracy = np.array([])
    val_accuracy = np.array([])

    l = np.array([])
    val_l = np.array([])


    P = Pruning(tf.keras.models.clone_model(model), 
                pruning_factor =p)
    lr = 1
    for epoch in [75,15,10]:
        # Paramètre d'entrainement
        lr /= 10
        P.compile(optimizer = tf.keras.optimizers.SGD(learning_rate=lr),
                 loss_fn = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                 metric = tf.keras.metrics.SparseCategoricalAccuracy(),
        )

        # Entrainement         
        accur, loss, val_accur, val_loss = P.train(x_train, y_train, 
                                                   x_test, y_test, 
                                                   epochs = epoch, 
                                                   batch_size= 32 )  


        # plot hist
        accuracy = np.append(accuracy, accur)
        val_accuracy = np.append(val_accuracy, val_accur)
        l = np.append(l, loss)
        val_l = np.append(val_l,val_loss)
    
    # Afficher les courbes d'entrainement
    #plot_hist(f"Lenet5_P_factor_{p}.png")
    
    # inference time
    pruned_inf_time = inference_time()
    
    # Enregister l'historique
    dico[f"P_factor_{p}_hist"] = (accuracy, val_accuracy, l, val_l)
    
    # calcul du temps d'inférence
    dico[f"P_factor_{p}_inf_time"] = pruned_inf_time

    
    # memory used
    dico[f"nb_params_p_factor_{p}"] = count_parameters(P.model)
    
    # sauvegarder les poids
    P.model.save_weights(f"w_Lenet5_p_{p}.h5")
# Out:
# Epoch (1/75)
# Accuracy: 0.9241 ; loss: 0.0140
# Validation Step :
# Accuracy: 0.9303 ; loss: 0.0044
# Accuracy Moy : 0.9268 ; loss Moy: 0.1030
#
# Epoch (2/75)
# Accuracy: 0.9516 ; loss: 0.0141
# Validation Step :
# Accuracy: 0.9533 ; loss: 0.0015
# Accuracy Moy : 0.9523 ; loss Moy: 0.0788
#
# Epoch (3/75)
# Accuracy: 0.9620 ; loss: 0.0068
# Validation Step :
# Accuracy: 0.9629 ; loss: 0.0004
# Accuracy Moy : 0.9623 ; loss Moy: 0.0617
#
# Epoch (4/75)
# Accuracy: 0.9680 ; loss: 0.0050
# Validation Step :
# Accuracy: 0.9685 ; loss: 0.0002
# Accuracy Moy : 0.9682 ; loss Moy: 0.0567
#
# Epoch (5/75)
# Accuracy: 0.9720 ; loss: 0.0047
# Validation Step :
# Accuracy: 0.9723 ; loss: 0.0001
# Accuracy Moy : 0.9721 ; loss Moy: 0.0539
#
# Epoch (6/75)
# Accuracy: 0.9749 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9751 ; loss: 0.0001
# Accuracy Moy : 0.9750 ; loss Moy: 0.0483
#
# Epoch (7/75)
# Accuracy: 0.9772 ; loss: 0.0016
# Validation Step :
# Accuracy: 0.9773 ; loss: 0.0001
# Accuracy Moy : 0.9772 ; loss Moy: 0.0508
#
# Epoch (8/75)
# Accuracy: 0.9790 ; loss: 0.0018
# Validation Step :
# Accuracy: 0.9791 ; loss: 0.0000
# Accuracy Moy : 0.9791 ; loss Moy: 0.0519
#
# Epoch (9/75)
# Accuracy: 0.9805 ; loss: 0.0054
# Validation Step :
# Accuracy: 0.9805 ; loss: 0.0000
# Accuracy Moy : 0.9805 ; loss Moy: 0.0594
#
# Epoch (10/75)
# Accuracy: 0.9817 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9817 ; loss: 0.0000
# Accuracy Moy : 0.9817 ; loss Moy: 0.0514
#
# Epoch (11/75)
# Accuracy: 0.9827 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9827 ; loss: 0.0000
# Accuracy Moy : 0.9827 ; loss Moy: 0.0544
#
# Epoch (12/75)
# Accuracy: 0.9836 ; loss: 0.0010
# Validation Step :
# Accuracy: 0.9836 ; loss: 0.0000
# Accuracy Moy : 0.9836 ; loss Moy: 0.0604
#
# Epoch (13/75)
# Accuracy: 0.9843 ; loss: 0.0076
# Validation Step :
# Accuracy: 0.9843 ; loss: 0.0000
# Accuracy Moy : 0.9843 ; loss Moy: 0.0552
#
# Epoch (14/75)
# Accuracy: 0.9850 ; loss: 0.0005
# Validation Step :
# Accuracy: 0.9850 ; loss: 0.0000
# Accuracy Moy : 0.9850 ; loss Moy: 0.0574
#
# Epoch (15/75)
# Accuracy: 0.9855 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9855 ; loss: 0.0000
# Accuracy Moy : 0.9855 ; loss Moy: 0.0632
#
# Epoch (16/75)
# Accuracy: 0.9861 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9861 ; loss: 0.0000
# Accuracy Moy : 0.9861 ; loss Moy: 0.0636
#
# Epoch (17/75)
# Accuracy: 0.9866 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9866 ; loss: 0.0000
# Accuracy Moy : 0.9866 ; loss Moy: 0.0545
#
# Epoch (18/75)
# Accuracy: 0.9871 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9871 ; loss: 0.0000
# Accuracy Moy : 0.9871 ; loss Moy: 0.0552
#
# Epoch (19/75)
# Accuracy: 0.9876 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9876 ; loss: 0.0000
# Accuracy Moy : 0.9875 ; loss Moy: 0.0569
#
# Epoch (20/75)
# Accuracy: 0.9880 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9880 ; loss: 0.0000
# Accuracy Moy : 0.9880 ; loss Moy: 0.0684
#
# Epoch (21/75)
# Accuracy: 0.9883 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9883 ; loss: 0.0000
# Accuracy Moy : 0.9883 ; loss Moy: 0.0707
#
# Epoch (22/75)
# Accuracy: 0.9886 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9886 ; loss: 0.0000
# Accuracy Moy : 0.9886 ; loss Moy: 0.0595
#
# Epoch (23/75)
# Accuracy: 0.9889 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9889 ; loss: 0.0000
# Accuracy Moy : 0.9889 ; loss Moy: 0.0611
#
# Epoch (24/75)
# Accuracy: 0.9892 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9892 ; loss: 0.0000
# Accuracy Moy : 0.9892 ; loss Moy: 0.0611
#
# Epoch (25/75)
# Accuracy: 0.9895 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9895 ; loss: 0.0000
# Accuracy Moy : 0.9895 ; loss Moy: 0.0574
#
# Epoch (26/75)
# Accuracy: 0.9898 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9898 ; loss: 0.0000
# Accuracy Moy : 0.9898 ; loss Moy: 0.0689
#
# Epoch (27/75)
# Accuracy: 0.9900 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9899 ; loss: 0.0000
# Accuracy Moy : 0.9900 ; loss Moy: 0.1001
#
# Epoch (28/75)
# Accuracy: 0.9902 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9902 ; loss: 0.0000
# Accuracy Moy : 0.9902 ; loss Moy: 0.0655
#
# Epoch (29/75)
# Accuracy: 0.9904 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9904 ; loss: 0.0000
# Accuracy Moy : 0.9904 ; loss Moy: 0.0675
#
# Epoch (30/75)
# Accuracy: 0.9906 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9906 ; loss: 0.0000
# Accuracy Moy : 0.9906 ; loss Moy: 0.0639
#
# Epoch (31/75)
# Accuracy: 0.9908 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9908 ; loss: 0.0000
# Accuracy Moy : 0.9908 ; loss Moy: 0.0591
#
# Epoch (32/75)
# Accuracy: 0.9910 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9910 ; loss: 0.0000
# Accuracy Moy : 0.9910 ; loss Moy: 0.0690
#
# Epoch (33/75)
# Accuracy: 0.9911 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9911 ; loss: 0.0000
# Accuracy Moy : 0.9911 ; loss Moy: 0.0640
#
# Epoch (34/75)
# Accuracy: 0.9913 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9913 ; loss: 0.0000
# Accuracy Moy : 0.9913 ; loss Moy: 0.0647
#
# Epoch (35/75)
# Accuracy: 0.9915 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9915 ; loss: 0.0000
# Accuracy Moy : 0.9915 ; loss Moy: 0.0588
#
# Epoch (36/75)
# Accuracy: 0.9917 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9916 ; loss: 0.0000
# Accuracy Moy : 0.9916 ; loss Moy: 0.0668
#
# Epoch (37/75)
# Accuracy: 0.9918 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9918 ; loss: 0.0000
# Accuracy Moy : 0.9918 ; loss Moy: 0.0667
#
# Epoch (38/75)
# Accuracy: 0.9920 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9920 ; loss: 0.0000
# Accuracy Moy : 0.9920 ; loss Moy: 0.0734
#
# Epoch (39/75)
# Accuracy: 0.9921 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9921 ; loss: 0.0000
# Accuracy Moy : 0.9921 ; loss Moy: 0.0775
#
# Epoch (40/75)
# Accuracy: 0.9922 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9922 ; loss: 0.0000
# Accuracy Moy : 0.9922 ; loss Moy: 0.0790
#
# Epoch (41/75)
# Accuracy: 0.9923 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9923 ; loss: 0.0000
# Accuracy Moy : 0.9923 ; loss Moy: 0.0804
#
# Epoch (42/75)
# Accuracy: 0.9924 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9924 ; loss: 0.0000
# Accuracy Moy : 0.9924 ; loss Moy: 0.0679
#
# Epoch (43/75)
# Accuracy: 0.9925 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9925 ; loss: 0.0000
# Accuracy Moy : 0.9925 ; loss Moy: 0.0702
#
# Epoch (44/75)
# Accuracy: 0.9926 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9926 ; loss: 0.0000
# Accuracy Moy : 0.9926 ; loss Moy: 0.0693
#
# Epoch (45/75)
# Accuracy: 0.9927 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9927 ; loss: 0.0000
# Accuracy Moy : 0.9927 ; loss Moy: 0.0695
#
# Epoch (46/75)
# Accuracy: 0.9929 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9928 ; loss: 0.0000
# Accuracy Moy : 0.9928 ; loss Moy: 0.0716
#
# Epoch (47/75)
# Accuracy: 0.9930 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9929 ; loss: 0.0000
# Accuracy Moy : 0.9929 ; loss Moy: 0.0703
#
# Epoch (48/75)
# Accuracy: 0.9930 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9930 ; loss: 0.0000
# Accuracy Moy : 0.9930 ; loss Moy: 0.0704
#
# Epoch (49/75)
# Accuracy: 0.9931 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9931 ; loss: 0.0000
# Accuracy Moy : 0.9931 ; loss Moy: 0.0706
#
# Epoch (50/75)
# Accuracy: 0.9932 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9932 ; loss: 0.0000
# Accuracy Moy : 0.9932 ; loss Moy: 0.0783
#
# Epoch (51/75)
# Accuracy: 0.9933 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9933 ; loss: 0.0000
# Accuracy Moy : 0.9933 ; loss Moy: 0.0725
#
# Epoch (52/75)
# Accuracy: 0.9934 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9933 ; loss: 0.0000
# Accuracy Moy : 0.9934 ; loss Moy: 0.0652
#
# Epoch (53/75)
# Accuracy: 0.9934 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9934 ; loss: 0.0000
# Accuracy Moy : 0.9934 ; loss Moy: 0.0799
#
# Epoch (54/75)
# Accuracy: 0.9935 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9935 ; loss: 0.0000
# Accuracy Moy : 0.9935 ; loss Moy: 0.0702
#
# Epoch (55/75)
# Accuracy: 0.9936 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9936 ; loss: 0.0000
# Accuracy Moy : 0.9936 ; loss Moy: 0.0784
#
# Epoch (56/75)
# Accuracy: 0.9937 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9936 ; loss: 0.0000
# Accuracy Moy : 0.9936 ; loss Moy: 0.0737
#
# Epoch (57/75)
# Accuracy: 0.9937 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9937 ; loss: 0.0000
# Accuracy Moy : 0.9937 ; loss Moy: 0.0686
#
# Epoch (58/75)
# Accuracy: 0.9938 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9938 ; loss: 0.0000
# Accuracy Moy : 0.9938 ; loss Moy: 0.0706
#
# Epoch (59/75)
# Accuracy: 0.9939 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9939 ; loss: 0.0000
# Accuracy Moy : 0.9939 ; loss Moy: 0.0738
#
# Epoch (60/75)
# Accuracy: 0.9939 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9939 ; loss: 0.0000
# Accuracy Moy : 0.9939 ; loss Moy: 0.0717
#
# Epoch (61/75)
# Accuracy: 0.9940 ; loss: 0.0054
# Validation Step :
# Accuracy: 0.9940 ; loss: 0.0000
# Accuracy Moy : 0.9940 ; loss Moy: 0.0768
#
# Epoch (62/75)
# Accuracy: 0.9941 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9941 ; loss: 0.0000
# Accuracy Moy : 0.9941 ; loss Moy: 0.0793
#
# Epoch (63/75)
# Accuracy: 0.9941 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9941 ; loss: 0.0000
# Accuracy Moy : 0.9941 ; loss Moy: 0.0726
#
# Epoch (64/75)
# Accuracy: 0.9942 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9942 ; loss: 0.0000
# Accuracy Moy : 0.9942 ; loss Moy: 0.0735
#
# Epoch (65/75)
# Accuracy: 0.9943 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9943 ; loss: 0.0000
# Accuracy Moy : 0.9943 ; loss Moy: 0.0746
#
# Epoch (66/75)
# Accuracy: 0.9943 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9943 ; loss: 0.0000
# Accuracy Moy : 0.9943 ; loss Moy: 0.0752
#
# Epoch (67/75)
# Accuracy: 0.9944 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9944 ; loss: 0.0000
# Accuracy Moy : 0.9944 ; loss Moy: 0.0759
#
# Epoch (68/75)
# Accuracy: 0.9945 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9945 ; loss: 0.0000
# Accuracy Moy : 0.9945 ; loss Moy: 0.0764
#
# Epoch (69/75)
# Accuracy: 0.9945 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9945 ; loss: 0.0000
# Accuracy Moy : 0.9945 ; loss Moy: 0.0768
#
# Epoch (70/75)
# Accuracy: 0.9946 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9946 ; loss: 0.0000
# Accuracy Moy : 0.9946 ; loss Moy: 0.0773
#
# Epoch (71/75)
# Accuracy: 0.9946 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9946 ; loss: 0.0000
# Accuracy Moy : 0.9946 ; loss Moy: 0.0777
#
# Epoch (72/75)
# Accuracy: 0.9947 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9947 ; loss: 0.0000
# Accuracy Moy : 0.9947 ; loss Moy: 0.0780
#
# Epoch (73/75)
# Accuracy: 0.9948 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9947 ; loss: 0.0000
# Accuracy Moy : 0.9947 ; loss Moy: 0.0784
#
# Epoch (74/75)
# Accuracy: 0.9948 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9948 ; loss: 0.0000
# Accuracy Moy : 0.9948 ; loss Moy: 0.0788
#
# Epoch (75/75)
# Accuracy: 0.9949 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9948 ; loss: 0.0000
# Accuracy Moy : 0.9949 ; loss Moy: 0.0791
#
# Epoch (1/15)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9991 ; loss Moy: 0.0791
#
# Epoch (2/15)
# Accuracy: 0.9993 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9989 ; loss Moy: 0.0792
#
# Epoch (3/15)
# Accuracy: 0.9991 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0792
#
# Epoch (4/15)
# Accuracy: 0.9990 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0792
#
# Epoch (5/15)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0793
#
# Epoch (6/15)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0793
#
# Epoch (7/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0793
#
# Epoch (8/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0793
#
# Epoch (9/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0794
#
# Epoch (10/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0794
#
# Epoch (11/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0794
#
# Epoch (12/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0795
#
# Epoch (13/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0795
#
# Epoch (14/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0795
#
# Epoch (15/15)
# Accuracy: 0.9987 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Epoch (1/10)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9991 ; loss Moy: 0.0796
#
# Epoch (2/10)
# Accuracy: 0.9993 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9989 ; loss Moy: 0.0796
#
# Epoch (3/10)
# Accuracy: 0.9991 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0796
#
# Epoch (4/10)
# Accuracy: 0.9990 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0796
#
# Epoch (5/10)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0796
#
# Epoch (6/10)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Epoch (7/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Epoch (8/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Epoch (9/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Epoch (10/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0796
#
# Scratch inference time :  0.4007049322128296  s
# Pruned inference time :  0.39716670513153074  s
# Epoch (1/75)
# Accuracy: 0.9129 ; loss: 0.0120
# Validation Step :
# Accuracy: 0.9206 ; loss: 0.0030
# Accuracy Moy : 0.9164 ; loss Moy: 0.1031
#
# Epoch (2/75)
# Accuracy: 0.9449 ; loss: 0.0073
# Validation Step :
# Accuracy: 0.9473 ; loss: 0.0052
# Accuracy Moy : 0.9459 ; loss Moy: 0.0682
#
# Epoch (3/75)
# Accuracy: 0.9574 ; loss: 0.0064
# Validation Step :
# Accuracy: 0.9585 ; loss: 0.0036
# Accuracy Moy : 0.9579 ; loss Moy: 0.0566
#
# Epoch (4/75)
# Accuracy: 0.9644 ; loss: 0.0035
# Validation Step :
# Accuracy: 0.9651 ; loss: 0.0074
# Accuracy Moy : 0.9647 ; loss Moy: 0.0533
#
# Epoch (5/75)
# Accuracy: 0.9690 ; loss: 0.0037
# Validation Step :
# Accuracy: 0.9695 ; loss: 0.0051
# Accuracy Moy : 0.9692 ; loss Moy: 0.0495
#
# Epoch (6/75)
# Accuracy: 0.9723 ; loss: 0.0025
# Validation Step :
# Accuracy: 0.9726 ; loss: 0.0027
# Accuracy Moy : 0.9724 ; loss Moy: 0.0507
#
# Epoch (7/75)
# Accuracy: 0.9749 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9751 ; loss: 0.0017
# Accuracy Moy : 0.9749 ; loss Moy: 0.0506
#
# Epoch (8/75)
# Accuracy: 0.9769 ; loss: 0.0025
# Validation Step :
# Accuracy: 0.9770 ; loss: 0.0062
# Accuracy Moy : 0.9769 ; loss Moy: 0.0545
#
# Epoch (9/75)
# Accuracy: 0.9785 ; loss: 0.0014
# Validation Step :
# Accuracy: 0.9786 ; loss: 0.0007
# Accuracy Moy : 0.9785 ; loss Moy: 0.0474
#
# Epoch (10/75)
# Accuracy: 0.9798 ; loss: 0.0008
# Validation Step :
# Accuracy: 0.9799 ; loss: 0.0001
# Accuracy Moy : 0.9798 ; loss Moy: 0.0494
#
# Epoch (11/75)
# Accuracy: 0.9810 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9811 ; loss: 0.0000
# Accuracy Moy : 0.9810 ; loss Moy: 0.0459
#
# Epoch (12/75)
# Accuracy: 0.9820 ; loss: 0.0023
# Validation Step :
# Accuracy: 0.9820 ; loss: 0.0003
# Accuracy Moy : 0.9820 ; loss Moy: 0.0560
#
# Epoch (13/75)
# Accuracy: 0.9829 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9829 ; loss: 0.0000
# Accuracy Moy : 0.9829 ; loss Moy: 0.0520
#
# Epoch (14/75)
# Accuracy: 0.9836 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9837 ; loss: 0.0000
# Accuracy Moy : 0.9836 ; loss Moy: 0.0501
#
# Epoch (15/75)
# Accuracy: 0.9844 ; loss: 0.0028
# Validation Step :
# Accuracy: 0.9844 ; loss: 0.0006
# Accuracy Moy : 0.9844 ; loss Moy: 0.0579
#
# Epoch (16/75)
# Accuracy: 0.9850 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9850 ; loss: 0.0000
# Accuracy Moy : 0.9850 ; loss Moy: 0.0541
#
# Epoch (17/75)
# Accuracy: 0.9856 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9855 ; loss: 0.0008
# Accuracy Moy : 0.9855 ; loss Moy: 0.0610
#
# Epoch (18/75)
# Accuracy: 0.9860 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9860 ; loss: 0.0001
# Accuracy Moy : 0.9860 ; loss Moy: 0.0553
#
# Epoch (19/75)
# Accuracy: 0.9865 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9865 ; loss: 0.0000
# Accuracy Moy : 0.9865 ; loss Moy: 0.0578
#
# Epoch (20/75)
# Accuracy: 0.9869 ; loss: 0.0128
# Validation Step :
# Accuracy: 0.9869 ; loss: 0.0000
# Accuracy Moy : 0.9869 ; loss Moy: 0.0620
#
# Epoch (21/75)
# Accuracy: 0.9873 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9873 ; loss: 0.0000
# Accuracy Moy : 0.9873 ; loss Moy: 0.0559
#
# Epoch (22/75)
# Accuracy: 0.9877 ; loss: 0.0008
# Validation Step :
# Accuracy: 0.9877 ; loss: 0.0000
# Accuracy Moy : 0.9877 ; loss Moy: 0.0525
#
# Epoch (23/75)
# Accuracy: 0.9880 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9880 ; loss: 0.0002
# Accuracy Moy : 0.9880 ; loss Moy: 0.0537
#
# Epoch (24/75)
# Accuracy: 0.9884 ; loss: 0.0176
# Validation Step :
# Accuracy: 0.9884 ; loss: 0.0000
# Accuracy Moy : 0.9883 ; loss Moy: 0.0647
#
# Epoch (25/75)
# Accuracy: 0.9887 ; loss: 0.0013
# Validation Step :
# Accuracy: 0.9887 ; loss: 0.0000
# Accuracy Moy : 0.9887 ; loss Moy: 0.0565
#
# Epoch (26/75)
# Accuracy: 0.9889 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9889 ; loss: 0.0000
# Accuracy Moy : 0.9889 ; loss Moy: 0.0649
#
# Epoch (27/75)
# Accuracy: 0.9892 ; loss: 0.0041
# Validation Step :
# Accuracy: 0.9892 ; loss: 0.0000
# Accuracy Moy : 0.9892 ; loss Moy: 0.0628
#
# Epoch (28/75)
# Accuracy: 0.9894 ; loss: 0.0014
# Validation Step :
# Accuracy: 0.9894 ; loss: 0.0000
# Accuracy Moy : 0.9894 ; loss Moy: 0.0632
#
# Epoch (29/75)
# Accuracy: 0.9897 ; loss: 0.0110
# Validation Step :
# Accuracy: 0.9897 ; loss: 0.0000
# Accuracy Moy : 0.9897 ; loss Moy: 0.0617
#
# Epoch (30/75)
# Accuracy: 0.9899 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9899 ; loss: 0.0000
# Accuracy Moy : 0.9899 ; loss Moy: 0.0688
#
# Epoch (31/75)
# Accuracy: 0.9901 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9901 ; loss: 0.0000
# Accuracy Moy : 0.9901 ; loss Moy: 0.0610
#
# Epoch (32/75)
# Accuracy: 0.9903 ; loss: 0.0044
# Validation Step :
# Accuracy: 0.9903 ; loss: 0.0000
# Accuracy Moy : 0.9903 ; loss Moy: 0.0582
#
# Epoch (33/75)
# Accuracy: 0.9905 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9905 ; loss: 0.0000
# Accuracy Moy : 0.9905 ; loss Moy: 0.0631
#
# Epoch (34/75)
# Accuracy: 0.9907 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9907 ; loss: 0.0000
# Accuracy Moy : 0.9907 ; loss Moy: 0.0713
#
# Epoch (35/75)
# Accuracy: 0.9909 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9909 ; loss: 0.0000
# Accuracy Moy : 0.9909 ; loss Moy: 0.0701
#
# Epoch (36/75)
# Accuracy: 0.9910 ; loss: 0.0014
# Validation Step :
# Accuracy: 0.9910 ; loss: 0.0000
# Accuracy Moy : 0.9910 ; loss Moy: 0.0613
#
# Epoch (37/75)
# Accuracy: 0.9912 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9912 ; loss: 0.0001
# Accuracy Moy : 0.9912 ; loss Moy: 0.0668
#
# Epoch (38/75)
# Accuracy: 0.9913 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9913 ; loss: 0.0000
# Accuracy Moy : 0.9913 ; loss Moy: 0.0607
#
# Epoch (39/75)
# Accuracy: 0.9915 ; loss: 0.0019
# Validation Step :
# Accuracy: 0.9915 ; loss: 0.0000
# Accuracy Moy : 0.9915 ; loss Moy: 0.0641
#
# Epoch (40/75)
# Accuracy: 0.9916 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9916 ; loss: 0.0000
# Accuracy Moy : 0.9916 ; loss Moy: 0.0796
#
# Epoch (41/75)
# Accuracy: 0.9917 ; loss: 0.0023
# Validation Step :
# Accuracy: 0.9917 ; loss: 0.0007
# Accuracy Moy : 0.9917 ; loss Moy: 0.0746
#
# Epoch (42/75)
# Accuracy: 0.9919 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9919 ; loss: 0.0000
# Accuracy Moy : 0.9919 ; loss Moy: 0.0745
#
# Epoch (43/75)
# Accuracy: 0.9920 ; loss: 0.0019
# Validation Step :
# Accuracy: 0.9919 ; loss: 0.0057
# Accuracy Moy : 0.9919 ; loss Moy: 0.0718
#
# Epoch (44/75)
# Accuracy: 0.9921 ; loss: 0.0007
# Validation Step :
# Accuracy: 0.9920 ; loss: 0.0000
# Accuracy Moy : 0.9921 ; loss Moy: 0.0747
#
# Epoch (45/75)
# Accuracy: 0.9922 ; loss: 0.0007
# Validation Step :
# Accuracy: 0.9922 ; loss: 0.0000
# Accuracy Moy : 0.9922 ; loss Moy: 0.0709
#
# Epoch (46/75)
# Accuracy: 0.9923 ; loss: 0.0045
# Validation Step :
# Accuracy: 0.9923 ; loss: 0.0000
# Accuracy Moy : 0.9923 ; loss Moy: 0.0829
#
# Epoch (47/75)
# Accuracy: 0.9924 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9924 ; loss: 0.0000
# Accuracy Moy : 0.9924 ; loss Moy: 0.0772
#
# Epoch (48/75)
# Accuracy: 0.9925 ; loss: 0.0025
# Validation Step :
# Accuracy: 0.9925 ; loss: 0.0000
# Accuracy Moy : 0.9925 ; loss Moy: 0.0747
#
# Epoch (49/75)
# Accuracy: 0.9926 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9926 ; loss: 0.0000
# Accuracy Moy : 0.9926 ; loss Moy: 0.0750
#
# Epoch (50/75)
# Accuracy: 0.9927 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9927 ; loss: 0.0000
# Accuracy Moy : 0.9927 ; loss Moy: 0.0779
#
# Epoch (51/75)
# Accuracy: 0.9928 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9928 ; loss: 0.0000
# Accuracy Moy : 0.9928 ; loss Moy: 0.0739
#
# Epoch (52/75)
# Accuracy: 0.9929 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9929 ; loss: 0.0000
# Accuracy Moy : 0.9929 ; loss Moy: 0.0750
#
# Epoch (53/75)
# Accuracy: 0.9930 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9930 ; loss: 0.0000
# Accuracy Moy : 0.9930 ; loss Moy: 0.0778
#
# Epoch (54/75)
# Accuracy: 0.9931 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9931 ; loss: 0.0000
# Accuracy Moy : 0.9931 ; loss Moy: 0.0705
#
# Epoch (55/75)
# Accuracy: 0.9932 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9932 ; loss: 0.0000
# Accuracy Moy : 0.9932 ; loss Moy: 0.0962
#
# Epoch (56/75)
# Accuracy: 0.9932 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9932 ; loss: 0.0000
# Accuracy Moy : 0.9932 ; loss Moy: 0.0672
#
# Epoch (57/75)
# Accuracy: 0.9933 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9933 ; loss: 0.0000
# Accuracy Moy : 0.9933 ; loss Moy: 0.0635
#
# Epoch (58/75)
# Accuracy: 0.9934 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9934 ; loss: 0.0000
# Accuracy Moy : 0.9934 ; loss Moy: 0.0637
#
# Epoch (59/75)
# Accuracy: 0.9935 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9935 ; loss: 0.0000
# Accuracy Moy : 0.9935 ; loss Moy: 0.0628
#
# Epoch (60/75)
# Accuracy: 0.9936 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9936 ; loss: 0.0000
# Accuracy Moy : 0.9936 ; loss Moy: 0.0637
#
# Epoch (61/75)
# Accuracy: 0.9937 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9937 ; loss: 0.0000
# Accuracy Moy : 0.9937 ; loss Moy: 0.0646
#
# Epoch (62/75)
# Accuracy: 0.9938 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9938 ; loss: 0.0000
# Accuracy Moy : 0.9938 ; loss Moy: 0.0653
#
# Epoch (63/75)
# Accuracy: 0.9938 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9938 ; loss: 0.0000
# Accuracy Moy : 0.9938 ; loss Moy: 0.0660
#
# Epoch (64/75)
# Accuracy: 0.9939 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9939 ; loss: 0.0000
# Accuracy Moy : 0.9939 ; loss Moy: 0.0666
#
# Epoch (65/75)
# Accuracy: 0.9940 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9940 ; loss: 0.0000
# Accuracy Moy : 0.9940 ; loss Moy: 0.0672
#
# Epoch (66/75)
# Accuracy: 0.9941 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9941 ; loss: 0.0000
# Accuracy Moy : 0.9941 ; loss Moy: 0.0677
#
# Epoch (67/75)
# Accuracy: 0.9941 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9941 ; loss: 0.0000
# Accuracy Moy : 0.9941 ; loss Moy: 0.0682
#
# Epoch (68/75)
# Accuracy: 0.9942 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9942 ; loss: 0.0000
# Accuracy Moy : 0.9942 ; loss Moy: 0.0687
#
# Epoch (69/75)
# Accuracy: 0.9943 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9943 ; loss: 0.0000
# Accuracy Moy : 0.9943 ; loss Moy: 0.0691
#
# Epoch (70/75)
# Accuracy: 0.9943 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9943 ; loss: 0.0000
# Accuracy Moy : 0.9943 ; loss Moy: 0.0694
#
# Epoch (71/75)
# Accuracy: 0.9944 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9944 ; loss: 0.0000
# Accuracy Moy : 0.9944 ; loss Moy: 0.0698
#
# Epoch (72/75)
# Accuracy: 0.9944 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9944 ; loss: 0.0000
# Accuracy Moy : 0.9944 ; loss Moy: 0.0701
#
# Epoch (73/75)
# Accuracy: 0.9945 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9945 ; loss: 0.0000
# Accuracy Moy : 0.9945 ; loss Moy: 0.0705
#
# Epoch (74/75)
# Accuracy: 0.9946 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9946 ; loss: 0.0000
# Accuracy Moy : 0.9946 ; loss Moy: 0.0708
#
# Epoch (75/75)
# Accuracy: 0.9946 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9946 ; loss: 0.0000
# Accuracy Moy : 0.9946 ; loss Moy: 0.0711
#
# Epoch (1/15)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9991 ; loss Moy: 0.0711
#
# Epoch (2/15)
# Accuracy: 0.9993 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9989 ; loss Moy: 0.0711
#
# Epoch (3/15)
# Accuracy: 0.9991 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0712
#
# Epoch (4/15)
# Accuracy: 0.9990 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0712
#
# Epoch (5/15)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0712
#
# Epoch (6/15)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0713
#
# Epoch (7/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0713
#
# Epoch (8/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0713
#
# Epoch (9/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0713
#
# Epoch (10/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0714
#
# Epoch (11/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0714
#
# Epoch (12/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0714
#
# Epoch (13/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (14/15)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (15/15)
# Accuracy: 0.9987 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (1/10)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9991 ; loss Moy: 0.0715
#
# Epoch (2/10)
# Accuracy: 0.9993 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9989 ; loss Moy: 0.0715
#
# Epoch (3/10)
# Accuracy: 0.9991 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0715
#
# Epoch (4/10)
# Accuracy: 0.9990 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0715
#
# Epoch (5/10)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.0715
#
# Epoch (6/10)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (7/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (8/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (9/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Epoch (10/10)
# Accuracy: 0.9988 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9987 ; loss: 0.0000
# Accuracy Moy : 0.9987 ; loss Moy: 0.0715
#
# Scratch inference time :  0.40097315311431886  s
# Pruned inference time :  0.3984829902648926  s
# Epoch (1/75)
# Accuracy: 0.9104 ; loss: 0.0492
# Validation Step :
# Accuracy: 0.9170 ; loss: 0.0064
# Accuracy Moy : 0.9134 ; loss Moy: 0.1333
#
# Epoch (2/75)
# Accuracy: 0.9405 ; loss: 0.0400
# Validation Step :
# Accuracy: 0.9419 ; loss: 0.0038
# Accuracy Moy : 0.9409 ; loss Moy: 0.1284
#
# Epoch (3/75)
# Accuracy: 0.9526 ; loss: 0.0169
# Validation Step :
# Accuracy: 0.9535 ; loss: 0.0024
# Accuracy Moy : 0.9529 ; loss Moy: 0.0941
#
# Epoch (4/75)
# Accuracy: 0.9598 ; loss: 0.0168
# Validation Step :
# Accuracy: 0.9604 ; loss: 0.0010
# Accuracy Moy : 0.9601 ; loss Moy: 0.0777
#
# Epoch (5/75)
# Accuracy: 0.9647 ; loss: 0.0098
# Validation Step :
# Accuracy: 0.9652 ; loss: 0.0006
# Accuracy Moy : 0.9649 ; loss Moy: 0.0675
#
# Epoch (6/75)
# Accuracy: 0.9683 ; loss: 0.0067
# Validation Step :
# Accuracy: 0.9686 ; loss: 0.0006
# Accuracy Moy : 0.9684 ; loss Moy: 0.0665
#
# Epoch (7/75)
# Accuracy: 0.9711 ; loss: 0.0050
# Validation Step :
# Accuracy: 0.9713 ; loss: 0.0010
# Accuracy Moy : 0.9712 ; loss Moy: 0.0667
#
# Epoch (8/75)
# Accuracy: 0.9733 ; loss: 0.0046
# Validation Step :
# Accuracy: 0.9734 ; loss: 0.0002
# Accuracy Moy : 0.9733 ; loss Moy: 0.0717
#
# Epoch (9/75)
# Accuracy: 0.9751 ; loss: 0.0021
# Validation Step :
# Accuracy: 0.9752 ; loss: 0.0001
# Accuracy Moy : 0.9751 ; loss Moy: 0.0691
#
# Epoch (10/75)
# Accuracy: 0.9766 ; loss: 0.0030
# Validation Step :
# Accuracy: 0.9766 ; loss: 0.0000
# Accuracy Moy : 0.9766 ; loss Moy: 0.0793
#
# Epoch (11/75)
# Accuracy: 0.9779 ; loss: 0.0195
# Validation Step :
# Accuracy: 0.9779 ; loss: 0.0000
# Accuracy Moy : 0.9779 ; loss Moy: 0.0758
#
# Epoch (12/75)
# Accuracy: 0.9790 ; loss: 0.0076
# Validation Step :
# Accuracy: 0.9790 ; loss: 0.0000
# Accuracy Moy : 0.9790 ; loss Moy: 0.0681
#
# Epoch (13/75)
# Accuracy: 0.9800 ; loss: 0.0081
# Validation Step :
# Accuracy: 0.9800 ; loss: 0.0011
# Accuracy Moy : 0.9799 ; loss Moy: 0.0733
#
# Epoch (14/75)
# Accuracy: 0.9808 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9808 ; loss: 0.0000
# Accuracy Moy : 0.9808 ; loss Moy: 0.0811
#
# Epoch (15/75)
# Accuracy: 0.9815 ; loss: 0.0114
# Validation Step :
# Accuracy: 0.9815 ; loss: 0.0000
# Accuracy Moy : 0.9815 ; loss Moy: 0.0655
#
# Epoch (16/75)
# Accuracy: 0.9822 ; loss: 0.0152
# Validation Step :
# Accuracy: 0.9822 ; loss: 0.0001
# Accuracy Moy : 0.9822 ; loss Moy: 0.0728
#
# Epoch (17/75)
# Accuracy: 0.9828 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9828 ; loss: 0.0003
# Accuracy Moy : 0.9828 ; loss Moy: 0.0721
#
# Epoch (18/75)
# Accuracy: 0.9834 ; loss: 0.0030
# Validation Step :
# Accuracy: 0.9834 ; loss: 0.0002
# Accuracy Moy : 0.9834 ; loss Moy: 0.0825
#
# Epoch (19/75)
# Accuracy: 0.9839 ; loss: 0.0070
# Validation Step :
# Accuracy: 0.9839 ; loss: 0.0001
# Accuracy Moy : 0.9839 ; loss Moy: 0.0746
#
# Epoch (20/75)
# Accuracy: 0.9844 ; loss: 0.0107
# Validation Step :
# Accuracy: 0.9844 ; loss: 0.0000
# Accuracy Moy : 0.9844 ; loss Moy: 0.0855
#
# Epoch (21/75)
# Accuracy: 0.9848 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9848 ; loss: 0.0001
# Accuracy Moy : 0.9848 ; loss Moy: 0.0719
#
# Epoch (22/75)
# Accuracy: 0.9853 ; loss: 0.0057
# Validation Step :
# Accuracy: 0.9853 ; loss: 0.0000
# Accuracy Moy : 0.9853 ; loss Moy: 0.0729
#
# Epoch (23/75)
# Accuracy: 0.9857 ; loss: 0.0297
# Validation Step :
# Accuracy: 0.9856 ; loss: 0.0002
# Accuracy Moy : 0.9856 ; loss Moy: 0.0966
#
# Epoch (24/75)
# Accuracy: 0.9860 ; loss: 0.0024
# Validation Step :
# Accuracy: 0.9860 ; loss: 0.0000
# Accuracy Moy : 0.9860 ; loss Moy: 0.0850
#
# Epoch (25/75)
# Accuracy: 0.9863 ; loss: 0.0192
# Validation Step :
# Accuracy: 0.9863 ; loss: 0.0017
# Accuracy Moy : 0.9863 ; loss Moy: 0.0931
#
# Epoch (26/75)
# Accuracy: 0.9866 ; loss: 0.0067
# Validation Step :
# Accuracy: 0.9866 ; loss: 0.0000
# Accuracy Moy : 0.9866 ; loss Moy: 0.0936
#
# Epoch (27/75)
# Accuracy: 0.9869 ; loss: 0.0076
# Validation Step :
# Accuracy: 0.9869 ; loss: 0.0000
# Accuracy Moy : 0.9869 ; loss Moy: 0.0841
#
# Epoch (28/75)
# Accuracy: 0.9872 ; loss: 0.1621
# Validation Step :
# Accuracy: 0.9872 ; loss: 0.0174
# Accuracy Moy : 0.9872 ; loss Moy: 0.0898
#
# Epoch (29/75)
# Accuracy: 0.9875 ; loss: 0.0058
# Validation Step :
# Accuracy: 0.9875 ; loss: 0.0004
# Accuracy Moy : 0.9875 ; loss Moy: 0.0813
#
# Epoch (30/75)
# Accuracy: 0.9877 ; loss: 0.0023
# Validation Step :
# Accuracy: 0.9877 ; loss: 0.0000
# Accuracy Moy : 0.9877 ; loss Moy: 0.0850
#
# Epoch (31/75)
# Accuracy: 0.9880 ; loss: 0.0008
# Validation Step :
# Accuracy: 0.9879 ; loss: 0.0000
# Accuracy Moy : 0.9879 ; loss Moy: 0.0943
#
# Epoch (32/75)
# Accuracy: 0.9882 ; loss: 0.0705
# Validation Step :
# Accuracy: 0.9882 ; loss: 0.0000
# Accuracy Moy : 0.9882 ; loss Moy: 0.0944
#
# Epoch (33/75)
# Accuracy: 0.9884 ; loss: 0.0139
# Validation Step :
# Accuracy: 0.9884 ; loss: 0.0001
# Accuracy Moy : 0.9884 ; loss Moy: 0.0922
#
# Epoch (34/75)
# Accuracy: 0.9886 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9886 ; loss: 0.0000
# Accuracy Moy : 0.9886 ; loss Moy: 0.0888
#
# Epoch (35/75)
# Accuracy: 0.9888 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9888 ; loss: 0.0000
# Accuracy Moy : 0.9888 ; loss Moy: 0.1092
#
# Epoch (36/75)
# Accuracy: 0.9890 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9890 ; loss: 0.0001
# Accuracy Moy : 0.9890 ; loss Moy: 0.0982
#
# Epoch (37/75)
# Accuracy: 0.9892 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9892 ; loss: 0.0000
# Accuracy Moy : 0.9892 ; loss Moy: 0.0868
#
# Epoch (38/75)
# Accuracy: 0.9893 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9893 ; loss: 0.0000
# Accuracy Moy : 0.9893 ; loss Moy: 0.0890
#
# Epoch (39/75)
# Accuracy: 0.9895 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9895 ; loss: 0.0003
# Accuracy Moy : 0.9895 ; loss Moy: 0.0992
#
# Epoch (40/75)
# Accuracy: 0.9897 ; loss: 0.0071
# Validation Step :
# Accuracy: 0.9897 ; loss: 0.0000
# Accuracy Moy : 0.9897 ; loss Moy: 0.1084
#
# Epoch (41/75)
# Accuracy: 0.9898 ; loss: 0.0135
# Validation Step :
# Accuracy: 0.9898 ; loss: 0.0000
# Accuracy Moy : 0.9898 ; loss Moy: 0.1092
#
# Epoch (42/75)
# Accuracy: 0.9899 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9899 ; loss: 0.0000
# Accuracy Moy : 0.9899 ; loss Moy: 0.0922
#
# Epoch (43/75)
# Accuracy: 0.9901 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9901 ; loss: 0.0000
# Accuracy Moy : 0.9901 ; loss Moy: 0.0926
#
# Epoch (44/75)
# Accuracy: 0.9902 ; loss: 0.0007
# Validation Step :
# Accuracy: 0.9902 ; loss: 0.0000
# Accuracy Moy : 0.9902 ; loss Moy: 0.0898
#
# Epoch (45/75)
# Accuracy: 0.9903 ; loss: 0.1938
# Validation Step :
# Accuracy: 0.9903 ; loss: 0.0001
# Accuracy Moy : 0.9903 ; loss Moy: 0.1036
#
# Epoch (46/75)
# Accuracy: 0.9904 ; loss: 0.0069
# Validation Step :
# Accuracy: 0.9904 ; loss: 0.0000
# Accuracy Moy : 0.9904 ; loss Moy: 0.0954
#
# Epoch (47/75)
# Accuracy: 0.9906 ; loss: 0.0186
# Validation Step :
# Accuracy: 0.9905 ; loss: 0.0000
# Accuracy Moy : 0.9905 ; loss Moy: 0.1031
#
# Epoch (48/75)
# Accuracy: 0.9907 ; loss: 0.0018
# Validation Step :
# Accuracy: 0.9907 ; loss: 0.0000
# Accuracy Moy : 0.9907 ; loss Moy: 0.1018
#
# Epoch (49/75)
# Accuracy: 0.9908 ; loss: 0.0024
# Validation Step :
# Accuracy: 0.9908 ; loss: 0.0000
# Accuracy Moy : 0.9908 ; loss Moy: 0.1042
#
# Epoch (50/75)
# Accuracy: 0.9909 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9909 ; loss: 0.0000
# Accuracy Moy : 0.9909 ; loss Moy: 0.0917
#
# Epoch (51/75)
# Accuracy: 0.9910 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9910 ; loss: 0.0000
# Accuracy Moy : 0.9910 ; loss Moy: 0.0964
#
# Epoch (52/75)
# Accuracy: 0.9911 ; loss: 0.0199
# Validation Step :
# Accuracy: 0.9911 ; loss: 0.0000
# Accuracy Moy : 0.9911 ; loss Moy: 0.1304
#
# Epoch (53/75)
# Accuracy: 0.9912 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9912 ; loss: 0.0000
# Accuracy Moy : 0.9912 ; loss Moy: 0.1034
#
# Epoch (54/75)
# Accuracy: 0.9913 ; loss: 0.0005
# Validation Step :
# Accuracy: 0.9913 ; loss: 0.0000
# Accuracy Moy : 0.9913 ; loss Moy: 0.1038
#
# Epoch (55/75)
# Accuracy: 0.9914 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9914 ; loss: 0.0000
# Accuracy Moy : 0.9914 ; loss Moy: 0.0952
#
# Epoch (56/75)
# Accuracy: 0.9915 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9915 ; loss: 0.0000
# Accuracy Moy : 0.9915 ; loss Moy: 0.0997
#
# Epoch (57/75)
# Accuracy: 0.9916 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9916 ; loss: 0.0000
# Accuracy Moy : 0.9916 ; loss Moy: 0.0979
#
# Epoch (58/75)
# Accuracy: 0.9917 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9917 ; loss: 0.0000
# Accuracy Moy : 0.9917 ; loss Moy: 0.1038
#
# Epoch (59/75)
# Accuracy: 0.9918 ; loss: 0.0011
# Validation Step :
# Accuracy: 0.9918 ; loss: 0.0000
# Accuracy Moy : 0.9918 ; loss Moy: 0.1222
#
# Epoch (60/75)
# Accuracy: 0.9919 ; loss: 0.0021
# Validation Step :
# Accuracy: 0.9919 ; loss: 0.0000
# Accuracy Moy : 0.9919 ; loss Moy: 0.1176
#
# Epoch (61/75)
# Accuracy: 0.9920 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9919 ; loss: 0.0000
# Accuracy Moy : 0.9920 ; loss Moy: 0.1148
#
# Epoch (62/75)
# Accuracy: 0.9920 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9920 ; loss: 0.0000
# Accuracy Moy : 0.9920 ; loss Moy: 0.1244
#
# Epoch (63/75)
# Accuracy: 0.9921 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9921 ; loss: 0.0000
# Accuracy Moy : 0.9921 ; loss Moy: 0.1186
#
# Epoch (64/75)
# Accuracy: 0.9921 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9921 ; loss: 0.0000
# Accuracy Moy : 0.9921 ; loss Moy: 0.1336
#
# Epoch (65/75)
# Accuracy: 0.9922 ; loss: 0.0068
# Validation Step :
# Accuracy: 0.9922 ; loss: 0.0000
# Accuracy Moy : 0.9922 ; loss Moy: 0.1360
#
# Epoch (66/75)
# Accuracy: 0.9923 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9923 ; loss: 0.0000
# Accuracy Moy : 0.9923 ; loss Moy: 0.1159
#
# Epoch (67/75)
# Accuracy: 0.9923 ; loss: 0.0072
# Validation Step :
# Accuracy: 0.9923 ; loss: 0.0000
# Accuracy Moy : 0.9923 ; loss Moy: 0.1254
#
# Epoch (68/75)
# Accuracy: 0.9924 ; loss: 0.0138
# Validation Step :
# Accuracy: 0.9924 ; loss: 0.0000
# Accuracy Moy : 0.9924 ; loss Moy: 0.1220
#
# Epoch (69/75)
# Accuracy: 0.9925 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9924 ; loss: 0.0000
# Accuracy Moy : 0.9924 ; loss Moy: 0.1106
#
# Epoch (70/75)
# Accuracy: 0.9925 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9925 ; loss: 0.0000
# Accuracy Moy : 0.9925 ; loss Moy: 0.1200
#
# Epoch (71/75)
# Accuracy: 0.9926 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9925 ; loss: 0.0000
# Accuracy Moy : 0.9925 ; loss Moy: 0.1247
#
# Epoch (72/75)
# Accuracy: 0.9926 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9926 ; loss: 0.0000
# Accuracy Moy : 0.9926 ; loss Moy: 0.1094
#
# Epoch (73/75)
# Accuracy: 0.9927 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9927 ; loss: 0.0000
# Accuracy Moy : 0.9927 ; loss Moy: 0.1202
#
# Epoch (74/75)
# Accuracy: 0.9927 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9927 ; loss: 0.0000
# Accuracy Moy : 0.9927 ; loss Moy: 0.1133
#
# Epoch (75/75)
# Accuracy: 0.9928 ; loss: 0.0307
# Validation Step :
# Accuracy: 0.9928 ; loss: 0.0000
# Accuracy Moy : 0.9928 ; loss Moy: 0.1092
#
# Epoch (1/15)
# Accuracy: 0.9998 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9986 ; loss Moy: 0.0954
#
# Epoch (2/15)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0954
#
# Epoch (3/15)
# Accuracy: 0.9986 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0956
#
# Epoch (4/15)
# Accuracy: 0.9985 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0959
#
# Epoch (5/15)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0961
#
# Epoch (6/15)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0964
#
# Epoch (7/15)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0966
#
# Epoch (8/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9981 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0968
#
# Epoch (9/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0970
#
# Epoch (10/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0972
#
# Epoch (11/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0973
#
# Epoch (12/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0975
#
# Epoch (13/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0977
#
# Epoch (14/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0978
#
# Epoch (15/15)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0980
#
# Epoch (1/10)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9989 ; loss Moy: 0.0980
#
# Epoch (2/10)
# Accuracy: 0.9990 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9985 ; loss Moy: 0.0980
#
# Epoch (3/10)
# Accuracy: 0.9987 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9984 ; loss Moy: 0.0980
#
# Epoch (4/10)
# Accuracy: 0.9986 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0980
#
# Epoch (5/10)
# Accuracy: 0.9985 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0981
#
# Epoch (6/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0981
#
# Epoch (7/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0981
#
# Epoch (8/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9983 ; loss Moy: 0.0981
#
# Epoch (9/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0981
#
# Epoch (10/10)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9982 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.0981
#
# Scratch inference time :  0.40006604194641116  s
# Pruned inference time :  0.3954888343811035  s
# Epoch (1/75)
# Accuracy: 0.8923 ; loss: 0.0119
# Validation Step :
# Accuracy: 0.9014 ; loss: 0.0017
# Accuracy Moy : 0.8967 ; loss Moy: 0.1337
#
# Epoch (2/75)
# Accuracy: 0.9315 ; loss: 0.0064
# Validation Step :
# Accuracy: 0.9341 ; loss: 0.0050
# Accuracy Moy : 0.9326 ; loss Moy: 0.0983
#
# Epoch (3/75)
# Accuracy: 0.9463 ; loss: 0.0057
# Validation Step :
# Accuracy: 0.9473 ; loss: 0.0024
# Accuracy Moy : 0.9466 ; loss Moy: 0.1053
#
# Epoch (4/75)
# Accuracy: 0.9545 ; loss: 0.0051
# Validation Step :
# Accuracy: 0.9550 ; loss: 0.0034
# Accuracy Moy : 0.9546 ; loss Moy: 0.0986
#
# Epoch (5/75)
# Accuracy: 0.9599 ; loss: 0.0024
# Validation Step :
# Accuracy: 0.9602 ; loss: 0.0001
# Accuracy Moy : 0.9600 ; loss Moy: 0.0896
#
# Epoch (6/75)
# Accuracy: 0.9638 ; loss: 0.0010
# Validation Step :
# Accuracy: 0.9641 ; loss: 0.0001
# Accuracy Moy : 0.9640 ; loss Moy: 0.0792
#
# Epoch (7/75)
# Accuracy: 0.9670 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9672 ; loss: 0.0003
# Accuracy Moy : 0.9670 ; loss Moy: 0.0717
#
# Epoch (8/75)
# Accuracy: 0.9694 ; loss: 0.0018
# Validation Step :
# Accuracy: 0.9696 ; loss: 0.0003
# Accuracy Moy : 0.9695 ; loss Moy: 0.0809
#
# Epoch (9/75)
# Accuracy: 0.9714 ; loss: 0.0010
# Validation Step :
# Accuracy: 0.9716 ; loss: 0.0001
# Accuracy Moy : 0.9715 ; loss Moy: 0.0747
#
# Epoch (10/75)
# Accuracy: 0.9731 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9732 ; loss: 0.0001
# Accuracy Moy : 0.9731 ; loss Moy: 0.0782
#
# Epoch (11/75)
# Accuracy: 0.9746 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9746 ; loss: 0.0000
# Accuracy Moy : 0.9746 ; loss Moy: 0.0794
#
# Epoch (12/75)
# Accuracy: 0.9757 ; loss: 0.0007
# Validation Step :
# Accuracy: 0.9758 ; loss: 0.0001
# Accuracy Moy : 0.9757 ; loss Moy: 0.0790
#
# Epoch (13/75)
# Accuracy: 0.9768 ; loss: 0.0417
# Validation Step :
# Accuracy: 0.9768 ; loss: 0.0001
# Accuracy Moy : 0.9768 ; loss Moy: 0.0730
#
# Epoch (14/75)
# Accuracy: 0.9778 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9778 ; loss: 0.0000
# Accuracy Moy : 0.9778 ; loss Moy: 0.0787
#
# Epoch (15/75)
# Accuracy: 0.9787 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9787 ; loss: 0.0000
# Accuracy Moy : 0.9787 ; loss Moy: 0.0755
#
# Epoch (16/75)
# Accuracy: 0.9794 ; loss: 0.0005
# Validation Step :
# Accuracy: 0.9794 ; loss: 0.0000
# Accuracy Moy : 0.9794 ; loss Moy: 0.0889
#
# Epoch (17/75)
# Accuracy: 0.9801 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9801 ; loss: 0.0000
# Accuracy Moy : 0.9801 ; loss Moy: 0.0827
#
# Epoch (18/75)
# Accuracy: 0.9807 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9808 ; loss: 0.0000
# Accuracy Moy : 0.9807 ; loss Moy: 0.0746
#
# Epoch (19/75)
# Accuracy: 0.9813 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9814 ; loss: 0.0000
# Accuracy Moy : 0.9813 ; loss Moy: 0.0769
#
# Epoch (20/75)
# Accuracy: 0.9819 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9819 ; loss: 0.0000
# Accuracy Moy : 0.9819 ; loss Moy: 0.1217
#
# Epoch (21/75)
# Accuracy: 0.9824 ; loss: 0.0010
# Validation Step :
# Accuracy: 0.9824 ; loss: 0.0000
# Accuracy Moy : 0.9824 ; loss Moy: 0.0913
#
# Epoch (22/75)
# Accuracy: 0.9829 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9828 ; loss: 0.0000
# Accuracy Moy : 0.9828 ; loss Moy: 0.0888
#
# Epoch (23/75)
# Accuracy: 0.9833 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9833 ; loss: 0.0000
# Accuracy Moy : 0.9833 ; loss Moy: 0.1055
#
# Epoch (24/75)
# Accuracy: 0.9837 ; loss: 0.0007
# Validation Step :
# Accuracy: 0.9837 ; loss: 0.0000
# Accuracy Moy : 0.9836 ; loss Moy: 0.0875
#
# Epoch (25/75)
# Accuracy: 0.9840 ; loss: 0.0017
# Validation Step :
# Accuracy: 0.9840 ; loss: 0.0000
# Accuracy Moy : 0.9840 ; loss Moy: 0.1002
#
# Epoch (26/75)
# Accuracy: 0.9844 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9844 ; loss: 0.0000
# Accuracy Moy : 0.9844 ; loss Moy: 0.0831
#
# Epoch (27/75)
# Accuracy: 0.9847 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9847 ; loss: 0.0000
# Accuracy Moy : 0.9847 ; loss Moy: 0.0918
#
# Epoch (28/75)
# Accuracy: 0.9851 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9850 ; loss: 0.0000
# Accuracy Moy : 0.9850 ; loss Moy: 0.1024
#
# Epoch (29/75)
# Accuracy: 0.9853 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9853 ; loss: 0.0000
# Accuracy Moy : 0.9853 ; loss Moy: 0.0987
#
# Epoch (30/75)
# Accuracy: 0.9856 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9856 ; loss: 0.0000
# Accuracy Moy : 0.9856 ; loss Moy: 0.0882
#
# Epoch (31/75)
# Accuracy: 0.9859 ; loss: 0.0017
# Validation Step :
# Accuracy: 0.9858 ; loss: 0.0000
# Accuracy Moy : 0.9859 ; loss Moy: 0.1196
#
# Epoch (32/75)
# Accuracy: 0.9861 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9861 ; loss: 0.0000
# Accuracy Moy : 0.9861 ; loss Moy: 0.0947
#
# Epoch (33/75)
# Accuracy: 0.9863 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9863 ; loss: 0.0000
# Accuracy Moy : 0.9863 ; loss Moy: 0.0962
#
# Epoch (34/75)
# Accuracy: 0.9866 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9866 ; loss: 0.0000
# Accuracy Moy : 0.9866 ; loss Moy: 0.1086
#
# Epoch (35/75)
# Accuracy: 0.9868 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9868 ; loss: 0.0000
# Accuracy Moy : 0.9868 ; loss Moy: 0.0952
#
# Epoch (36/75)
# Accuracy: 0.9871 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9870 ; loss: 0.0000
# Accuracy Moy : 0.9870 ; loss Moy: 0.0990
#
# Epoch (37/75)
# Accuracy: 0.9873 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9872 ; loss: 0.0000
# Accuracy Moy : 0.9873 ; loss Moy: 0.1018
#
# Epoch (38/75)
# Accuracy: 0.9875 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9875 ; loss: 0.0000
# Accuracy Moy : 0.9875 ; loss Moy: 0.0978
#
# Epoch (39/75)
# Accuracy: 0.9877 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9876 ; loss: 0.0000
# Accuracy Moy : 0.9876 ; loss Moy: 0.1121
#
# Epoch (40/75)
# Accuracy: 0.9878 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9878 ; loss: 0.0000
# Accuracy Moy : 0.9878 ; loss Moy: 0.0936
#
# Epoch (41/75)
# Accuracy: 0.9880 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9880 ; loss: 0.0000
# Accuracy Moy : 0.9880 ; loss Moy: 0.0968
#
# Epoch (42/75)
# Accuracy: 0.9882 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9882 ; loss: 0.0000
# Accuracy Moy : 0.9882 ; loss Moy: 0.1254
#
# Epoch (43/75)
# Accuracy: 0.9884 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9884 ; loss: 0.0000
# Accuracy Moy : 0.9884 ; loss Moy: 0.0951
#
# Epoch (44/75)
# Accuracy: 0.9885 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9885 ; loss: 0.0000
# Accuracy Moy : 0.9885 ; loss Moy: 0.1141
#
# Epoch (45/75)
# Accuracy: 0.9887 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9887 ; loss: 0.0000
# Accuracy Moy : 0.9887 ; loss Moy: 0.0973
#
# Epoch (46/75)
# Accuracy: 0.9888 ; loss: 0.0023
# Validation Step :
# Accuracy: 0.9888 ; loss: 0.0000
# Accuracy Moy : 0.9888 ; loss Moy: 0.1059
#
# Epoch (47/75)
# Accuracy: 0.9890 ; loss: 0.0000
# ...
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1127
#
# Epoch (12/15)
# Accuracy: 0.9980 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1131
#
# Epoch (13/15)
# Accuracy: 0.9980 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1135
#
# Epoch (14/15)
# Accuracy: 0.9980 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1139
#
# Epoch (15/15)
# Accuracy: 0.9980 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9979 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1143
#
# Epoch (1/10)
# Accuracy: 1.0000 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9988 ; loss Moy: 0.1143
#
# Epoch (2/10)
# Accuracy: 0.9989 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9984 ; loss Moy: 0.1144
#
# Epoch (3/10)
# Accuracy: 0.9986 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.1144
#
# Epoch (4/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9982 ; loss Moy: 0.1144
#
# Epoch (5/10)
# Accuracy: 0.9984 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1145
#
# Epoch (6/10)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1145
#
# Epoch (7/10)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1145
#
# Epoch (8/10)
# Accuracy: 0.9982 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1146
#
# Epoch (9/10)
# Accuracy: 0.9982 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1146
#
# Epoch (10/10)
# Accuracy: 0.9982 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9980 ; loss: 0.0000
# Accuracy Moy : 0.9981 ; loss Moy: 0.1146
#
# Scratch inference time :  0.4029565334320068  s
# Pruned inference time :  0.39860711097717283  s
# Epoch (1/75)
# Accuracy: 0.8036 ; loss: 0.1136
# Validation Step :
# Accuracy: 0.8192 ; loss: 0.0994
# Accuracy Moy : 0.8111 ; loss Moy: 0.2630
#
# Epoch (2/75)
# Accuracy: 0.8773 ; loss: 0.1269
# Validation Step :
# Accuracy: 0.8824 ; loss: 0.0146
# Accuracy Moy : 0.8797 ; loss Moy: 0.1637
#
# Epoch (3/75)
# Accuracy: 0.9060 ; loss: 0.0245
# Validation Step :
# Accuracy: 0.9084 ; loss: 0.0060
# Accuracy Moy : 0.9071 ; loss Moy: 0.1345
#
# Epoch (4/75)
# Accuracy: 0.9214 ; loss: 0.0156
# Validation Step :
# Accuracy: 0.9229 ; loss: 0.0038
# Accuracy Moy : 0.9221 ; loss Moy: 0.1265
#
# Epoch (5/75)
# Accuracy: 0.9313 ; loss: 0.0144
# Validation Step :
# Accuracy: 0.9322 ; loss: 0.0069
# Accuracy Moy : 0.9317 ; loss Moy: 0.1191
#
# Epoch (6/75)
# Accuracy: 0.9383 ; loss: 0.0214
# Validation Step :
# Accuracy: 0.9390 ; loss: 0.0015
# Accuracy Moy : 0.9386 ; loss Moy: 0.1147
#
# Epoch (7/75)
# Accuracy: 0.9435 ; loss: 0.0171
# Validation Step :
# Accuracy: 0.9440 ; loss: 0.0041
# Accuracy Moy : 0.9437 ; loss Moy: 0.1142
#
# Epoch (8/75)
# Accuracy: 0.9476 ; loss: 0.0171
# Validation Step :
# Accuracy: 0.9479 ; loss: 0.0033
# Accuracy Moy : 0.9477 ; loss Moy: 0.1177
#
# Epoch (9/75)
# Accuracy: 0.9508 ; loss: 0.0097
# Validation Step :
# Accuracy: 0.9511 ; loss: 0.0023
# Accuracy Moy : 0.9509 ; loss Moy: 0.1112
#
# Epoch (10/75)
# Accuracy: 0.9536 ; loss: 0.0868
# Validation Step :
# Accuracy: 0.9538 ; loss: 0.0033
# Accuracy Moy : 0.9537 ; loss Moy: 0.1108
#
# Epoch (11/75)
# Accuracy: 0.9560 ; loss: 0.0176
# Validation Step :
# Accuracy: 0.9561 ; loss: 0.0030
# Accuracy Moy : 0.9560 ; loss Moy: 0.1010
#
# Epoch (12/75)
# Accuracy: 0.9580 ; loss: 0.0828
# Validation Step :
# Accuracy: 0.9582 ; loss: 0.0101
# Accuracy Moy : 0.9581 ; loss Moy: 0.1138
#
# Epoch (13/75)
# Accuracy: 0.9598 ; loss: 0.0652
# Validation Step :
# Accuracy: 0.9599 ; loss: 0.0050
# Accuracy Moy : 0.9598 ; loss Moy: 0.1106
#
# Epoch (14/75)
# Accuracy: 0.9614 ; loss: 0.0067
# Validation Step :
# Accuracy: 0.9615 ; loss: 0.0018
# Accuracy Moy : 0.9614 ; loss Moy: 0.1128
#
# Epoch (15/75)
# Accuracy: 0.9628 ; loss: 0.0074
# Validation Step :
# Accuracy: 0.9629 ; loss: 0.0020
# Accuracy Moy : 0.9628 ; loss Moy: 0.1054
#
# Epoch (16/75)
# Accuracy: 0.9640 ; loss: 0.0614
# Validation Step :
# Accuracy: 0.9641 ; loss: 0.0006
# Accuracy Moy : 0.9640 ; loss Moy: 0.1112
#
# Epoch (17/75)
# Accuracy: 0.9651 ; loss: 0.0024
# Validation Step :
# Accuracy: 0.9651 ; loss: 0.0007
# Accuracy Moy : 0.9651 ; loss Moy: 0.1132
#
# Epoch (18/75)
# Accuracy: 0.9660 ; loss: 0.0034
# Validation Step :
# Accuracy: 0.9661 ; loss: 0.0008
# Accuracy Moy : 0.9660 ; loss Moy: 0.1137
#
# Epoch (19/75)
# Accuracy: 0.9669 ; loss: 0.0028
# Validation Step :
# Accuracy: 0.9669 ; loss: 0.0027
# Accuracy Moy : 0.9669 ; loss Moy: 0.1204
#
# Epoch (20/75)
# Accuracy: 0.9678 ; loss: 0.1172
# Validation Step :
# Accuracy: 0.9678 ; loss: 0.0067
# Accuracy Moy : 0.9677 ; loss Moy: 0.1236
#
# Epoch (21/75)
# Accuracy: 0.9685 ; loss: 0.0043
# Validation Step :
# Accuracy: 0.9685 ; loss: 0.0003
# Accuracy Moy : 0.9685 ; loss Moy: 0.1190
#
# Epoch (22/75)
# Accuracy: 0.9692 ; loss: 0.0025
# Validation Step :
# Accuracy: 0.9692 ; loss: 0.0020
# Accuracy Moy : 0.9692 ; loss Moy: 0.1127
#
# Epoch (23/75)
# Accuracy: 0.9699 ; loss: 0.0176
# Validation Step :
# Accuracy: 0.9699 ; loss: 0.0011
# Accuracy Moy : 0.9699 ; loss Moy: 0.1170
#
# Epoch (24/75)
# Accuracy: 0.9705 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9705 ; loss: 0.0001
# Accuracy Moy : 0.9705 ; loss Moy: 0.1159
#
# Epoch (25/75)
# Accuracy: 0.9711 ; loss: 0.0870
# Validation Step :
# Accuracy: 0.9711 ; loss: 0.0000
# Accuracy Moy : 0.9711 ; loss Moy: 0.1320
#
# Epoch (26/75)
# Accuracy: 0.9717 ; loss: 0.0011
# Validation Step :
# Accuracy: 0.9717 ; loss: 0.0003
# Accuracy Moy : 0.9716 ; loss Moy: 0.1231
#
# Epoch (27/75)
# Accuracy: 0.9722 ; loss: 0.0071
# Validation Step :
# Accuracy: 0.9722 ; loss: 0.0000
# Accuracy Moy : 0.9722 ; loss Moy: 0.1213
#
# Epoch (28/75)
# Accuracy: 0.9727 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9727 ; loss: 0.0001
# Accuracy Moy : 0.9727 ; loss Moy: 0.1266
#
# Epoch (29/75)
# Accuracy: 0.9731 ; loss: 0.1610
# Validation Step :
# Accuracy: 0.9731 ; loss: 0.0001
# Accuracy Moy : 0.9731 ; loss Moy: 0.1375
#
# Epoch (30/75)
# Accuracy: 0.9736 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9735 ; loss: 0.0000
# Accuracy Moy : 0.9735 ; loss Moy: 0.1460
#
# Epoch (31/75)
# Accuracy: 0.9740 ; loss: 0.0015
# Validation Step :
# Accuracy: 0.9739 ; loss: 0.0003
# Accuracy Moy : 0.9739 ; loss Moy: 0.1462
#
# Epoch (32/75)
# Accuracy: 0.9743 ; loss: 0.0016
# Validation Step :
# Accuracy: 0.9743 ; loss: 0.0010
# Accuracy Moy : 0.9743 ; loss Moy: 0.1253
#
# Epoch (33/75)
# Accuracy: 0.9747 ; loss: 0.0030
# Validation Step :
# Accuracy: 0.9747 ; loss: 0.0005
# Accuracy Moy : 0.9747 ; loss Moy: 0.1320
#
# Epoch (34/75)
# Accuracy: 0.9751 ; loss: 0.0061
# Validation Step :
# Accuracy: 0.9751 ; loss: 0.0002
# Accuracy Moy : 0.9751 ; loss Moy: 0.1390
#
# Epoch (35/75)
# Accuracy: 0.9754 ; loss: 0.0006
# Validation Step :
# Accuracy: 0.9754 ; loss: 0.0000
# Accuracy Moy : 0.9754 ; loss Moy: 0.1531
#
# Epoch (36/75)
# Accuracy: 0.9758 ; loss: 0.0004
# Validation Step :
# Accuracy: 0.9757 ; loss: 0.0000
# Accuracy Moy : 0.9757 ; loss Moy: 0.1548
#
# Epoch (37/75)
# Accuracy: 0.9760 ; loss: 0.0009
# Validation Step :
# Accuracy: 0.9760 ; loss: 0.0002
# Accuracy Moy : 0.9760 ; loss Moy: 0.1255
#
# Epoch (38/75)
# Accuracy: 0.9764 ; loss: 0.0267
# Validation Step :
# Accuracy: 0.9763 ; loss: 0.0003
# Accuracy Moy : 0.9763 ; loss Moy: 0.1351
#
# Epoch (39/75)
# Accuracy: 0.9766 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9766 ; loss: 0.0000
# Accuracy Moy : 0.9766 ; loss Moy: 0.1458
#
# Epoch (40/75)
# Accuracy: 0.9769 ; loss: 0.0029
# Validation Step :
# Accuracy: 0.9769 ; loss: 0.0001
# Accuracy Moy : 0.9769 ; loss Moy: 0.1435
#
# Epoch (41/75)
# Accuracy: 0.9771 ; loss: 0.0011
# Validation Step :
# Accuracy: 0.9771 ; loss: 0.0053
# Accuracy Moy : 0.9771 ; loss Moy: 0.1365
#
# Epoch (42/75)
# Accuracy: 0.9774 ; loss: 0.0010
# Validation Step :
# Accuracy: 0.9774 ; loss: 0.0000
# Accuracy Moy : 0.9774 ; loss Moy: 0.1429
#
# Epoch (43/75)
# Accuracy: 0.9776 ; loss: 0.0012
# Validation Step :
# Accuracy: 0.9776 ; loss: 0.0011
# Accuracy Moy : 0.9776 ; loss Moy: 0.1481
#
# Epoch (44/75)
# Accuracy: 0.9779 ; loss: 0.0037
# Validation Step :
# Accuracy: 0.9779 ; loss: 0.0000
# Accuracy Moy : 0.9779 ; loss Moy: 0.1449
#
# Epoch (45/75)
# Accuracy: 0.9781 ; loss: 0.0807
# Validation Step :
# Accuracy: 0.9781 ; loss: 0.0000
# Accuracy Moy : 0.9781 ; loss Moy: 0.1637
#
# Epoch (46/75)
# Accuracy: 0.9783 ; loss: 0.0035
# Validation Step :
# Accuracy: 0.9783 ; loss: 0.0018
# Accuracy Moy : 0.9783 ; loss Moy: 0.1541
#
# Epoch (47/75)
# Accuracy: 0.9785 ; loss: 0.0011
# Validation Step :
# Accuracy: 0.9785 ; loss: 0.0005
# Accuracy Moy : 0.9785 ; loss Moy: 0.1595
#
# Epoch (48/75)
# Accuracy: 0.9787 ; loss: 0.0384
# Validation Step :
# Accuracy: 0.9787 ; loss: 0.0010
# Accuracy Moy : 0.9787 ; loss Moy: 0.1439
#
# Epoch (49/75)
# Accuracy: 0.9789 ; loss: 0.0211
# Validation Step :
# Accuracy: 0.9789 ; loss: 0.0002
# Accuracy Moy : 0.9789 ; loss Moy: 0.1394
#
# Epoch (50/75)
# Accuracy: 0.9791 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9791 ; loss: 0.0002
# Accuracy Moy : 0.9791 ; loss Moy: 0.1464
#
# Epoch (51/75)
# Accuracy: 0.9793 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9792 ; loss: 0.0626
# Accuracy Moy : 0.9793 ; loss Moy: 0.1634
#
# Epoch (52/75)
# Accuracy: 0.9794 ; loss: 0.0024
# Validation Step :
# Accuracy: 0.9794 ; loss: 0.0000
# Accuracy Moy : 0.9794 ; loss Moy: 0.1396
#
# Epoch (53/75)
# Accuracy: 0.9796 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9796 ; loss: 0.0000
# Accuracy Moy : 0.9796 ; loss Moy: 0.1759
#
# Epoch (54/75)
# Accuracy: 0.9798 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9798 ; loss: 0.0105
# Accuracy Moy : 0.9798 ; loss Moy: 0.1503
#
# Epoch (55/75)
# Accuracy: 0.9799 ; loss: 0.0427
# Validation Step :
# Accuracy: 0.9799 ; loss: 0.0036
# Accuracy Moy : 0.9799 ; loss Moy: 0.1758
#
# Epoch (56/75)
# Accuracy: 0.9801 ; loss: 0.0053
# Validation Step :
# Accuracy: 0.9801 ; loss: 0.0053
# Accuracy Moy : 0.9801 ; loss Moy: 0.1647
#
# Epoch (57/75)
# Accuracy: 0.9802 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9802 ; loss: 0.0000
# Accuracy Moy : 0.9802 ; loss Moy: 0.1766
#
# Epoch (58/75)
# Accuracy: 0.9804 ; loss: 0.0003
# Validation Step :
# Accuracy: 0.9804 ; loss: 0.0000
# Accuracy Moy : 0.9804 ; loss Moy: 0.1594
#
# Epoch (59/75)
# Accuracy: 0.9805 ; loss: 0.0002
# Validation Step :
# Accuracy: 0.9805 ; loss: 0.0000
# Accuracy Moy : 0.9805 ; loss Moy: 0.1566
#
# Epoch (60/75)
# Accuracy: 0.9807 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9806 ; loss: 0.0000
# Accuracy Moy : 0.9807 ; loss Moy: 0.1801
#
# Epoch (61/75)
# Accuracy: 0.9808 ; loss: 0.4672
# Validation Step :
# Accuracy: 0.9808 ; loss: 0.0015
# Accuracy Moy : 0.9808 ; loss Moy: 0.1547
#
# Epoch (62/75)
# Accuracy: 0.9809 ; loss: 0.0104
# Validation Step :
# Accuracy: 0.9809 ; loss: 0.0035
# Accuracy Moy : 0.9809 ; loss Moy: 0.1776
#
# Epoch (63/75)
# Accuracy: 0.9811 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9810 ; loss: 0.0004
# Accuracy Moy : 0.9810 ; loss Moy: 0.1531
#
# Epoch (64/75)
# Accuracy: 0.9812 ; loss: 0.2976
# Validation Step :
# Accuracy: 0.9812 ; loss: 0.0000
# Accuracy Moy : 0.9812 ; loss Moy: 0.1776
#
# Epoch (65/75)
# Accuracy: 0.9813 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9813 ; loss: 0.0099
# Accuracy Moy : 0.9813 ; loss Moy: 0.1556
#
# Epoch (66/75)
# Accuracy: 0.9814 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9814 ; loss: 0.0029
# Accuracy Moy : 0.9814 ; loss Moy: 0.1644
#
# Epoch (67/75)
# Accuracy: 0.9815 ; loss: 0.0031
# Validation Step :
# Accuracy: 0.9815 ; loss: 0.0000
# Accuracy Moy : 0.9815 ; loss Moy: 0.2079
#
# Epoch (68/75)
# Accuracy: 0.9816 ; loss: 0.0059
# Validation Step :
# Accuracy: 0.9816 ; loss: 0.0243
# Accuracy Moy : 0.9816 ; loss Moy: 0.2063
#
# Epoch (69/75)
# Accuracy: 0.9817 ; loss: 0.0226
# Validation Step :
# Accuracy: 0.9817 ; loss: 0.0000
# Accuracy Moy : 0.9817 ; loss Moy: 0.1765
#
# Epoch (70/75)
# Accuracy: 0.9818 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9818 ; loss: 0.0000
# Accuracy Moy : 0.9818 ; loss Moy: 0.1831
#
# Epoch (71/75)
# Accuracy: 0.9819 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9819 ; loss: 0.0000
# Accuracy Moy : 0.9819 ; loss Moy: 0.1660
#
# Epoch (72/75)
# Accuracy: 0.9820 ; loss: 0.0034
# Validation Step :
# Accuracy: 0.9820 ; loss: 0.0000
# Accuracy Moy : 0.9820 ; loss Moy: 0.2018
#
# Epoch (73/75)
# Accuracy: 0.9821 ; loss: 0.0001
# Validation Step :
# Accuracy: 0.9821 ; loss: 0.0003
# Accuracy Moy : 0.9821 ; loss Moy: 0.1754
#
# Epoch (74/75)
# Accuracy: 0.9822 ; loss: 0.0885
# Validation Step :
# Accuracy: 0.9822 ; loss: 0.0002
# Accuracy Moy : 0.9822 ; loss Moy: 0.1819
#
# Epoch (75/75)
# Accuracy: 0.9823 ; loss: 0.0097
# Validation Step :
# Accuracy: 0.9823 ; loss: 0.0001
# Accuracy Moy : 0.9823 ; loss Moy: 0.1908
#
# Epoch (1/15)
# Accuracy: 0.9957 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9930 ; loss: 0.0000
# Accuracy Moy : 0.9940 ; loss Moy: 0.1498
#
# Epoch (2/15)
# Accuracy: 0.9954 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9941 ; loss: 0.0000
# Accuracy Moy : 0.9946 ; loss Moy: 0.1494
#
# Epoch (3/15)
# Accuracy: 0.9956 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9947 ; loss: 0.0000
# Accuracy Moy : 0.9950 ; loss Moy: 0.1510
#
# Epoch (4/15)
# Accuracy: 0.9957 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9951 ; loss: 0.0000
# Accuracy Moy : 0.9953 ; loss Moy: 0.1526
#
# Epoch (5/15)
# Accuracy: 0.9959 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9954 ; loss: 0.0000
# Accuracy Moy : 0.9956 ; loss Moy: 0.1539
#
# Epoch (6/15)
# Accuracy: 0.9960 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9956 ; loss: 0.0000
# Accuracy Moy : 0.9957 ; loss Moy: 0.1555
#
# Epoch (7/15)
# Accuracy: 0.9961 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9957 ; loss: 0.0000
# Accuracy Moy : 0.9958 ; loss Moy: 0.1569
#
# Epoch (8/15)
# Accuracy: 0.9962 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9958 ; loss: 0.0000
# Accuracy Moy : 0.9960 ; loss Moy: 0.1583
#
# Epoch (9/15)
# Accuracy: 0.9962 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9959 ; loss: 0.0000
# Accuracy Moy : 0.9960 ; loss Moy: 0.1597
#
# Epoch (10/15)
# Accuracy: 0.9963 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9960 ; loss: 0.0000
# Accuracy Moy : 0.9961 ; loss Moy: 0.1611
#
# Epoch (11/15)
# Accuracy: 0.9963 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9961 ; loss: 0.0000
# Accuracy Moy : 0.9962 ; loss Moy: 0.1623
#
# Epoch (12/15)
# Accuracy: 0.9964 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9962 ; loss: 0.0000
# Accuracy Moy : 0.9962 ; loss Moy: 0.1634
#
# Epoch (13/15)
# Accuracy: 0.9964 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9962 ; loss: 0.0000
# Accuracy Moy : 0.9963 ; loss Moy: 0.1646
#
# Epoch (14/15)
# Accuracy: 0.9964 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9963 ; loss: 0.0000
# Accuracy Moy : 0.9963 ; loss Moy: 0.1657
#
# Epoch (15/15)
# Accuracy: 0.9965 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9963 ; loss: 0.0000
# Accuracy Moy : 0.9964 ; loss Moy: 0.1669
#
# Epoch (1/10)
# Accuracy: 0.9999 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9980 ; loss Moy: 0.1669
#
# Epoch (2/10)
# Accuracy: 0.9983 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9974 ; loss Moy: 0.1669
#
# Epoch (3/10)
# Accuracy: 0.9978 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9972 ; loss Moy: 0.1670
#
# Epoch (4/10)
# Accuracy: 0.9976 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9971 ; loss Moy: 0.1671
#
# Epoch (5/10)
# Accuracy: 0.9974 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9971 ; loss Moy: 0.1671
#
# Epoch (6/10)
# Accuracy: 0.9973 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9971 ; loss Moy: 0.1672
#
# Epoch (7/10)
# Accuracy: 0.9973 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9970 ; loss Moy: 0.1673
#
# Epoch (8/10)
# Accuracy: 0.9972 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9970 ; loss Moy: 0.1674
#
# Epoch (9/10)
# Accuracy: 0.9972 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9970 ; loss Moy: 0.1675
#
# Epoch (10/10)
# Accuracy: 0.9972 ; loss: 0.0000
# Validation Step :
# Accuracy: 0.9969 ; loss: 0.0000
# Accuracy Moy : 0.9970 ; loss Moy: 0.1676
#
# Scratch inference time :  0.4003500699996948  s
# Pruned inference time :  0.40255978107452395  s

# %% [markdown]
# ## Evaluation des performances

# %%
def eval_plot(dic, figname, scratch = False):
    plt.figure(figsize=(15,15))
    for p in [0.5, 0.6, 0.7, 0.8, 0.9]:
        # Train accuracy
        plt.subplot(221)
        plt.plot(dic[f"P_factor_{p}_hist"][0], label = f"{p}")

        plt.title("Train accuracy")
        plt.grid()
        plt.legend()

        # Validation accuracy
        plt.subplot(222)
        plt.plot(dico[f"P_factor_{p}_hist"][1], label = f"{p}")

        plt.title("Validation accuracy")
        plt.grid()
        plt.legend()

        # train loss
        plt.subplot(223)
        plt.plot(dic[f"P_factor_{p}_hist"][2], label = f"{p}")

        plt.title("Train loss")
        plt.grid()
        plt.legend()

        # validation loss
        plt.subplot(224)
        plt.plot(dic[f"P_factor_{p}_hist"][3], label = f"{p}")

        plt.title("Validation loss")
        plt.grid()
        plt.legend()
        
    if scratch == True: 
        # Courbe scratch
        plt.subplot(221)
        plt.plot(dic["scratch_hist"][0], label = "Scratch Train accur")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy Value")

        plt.subplot(222)
        plt.plot(dic["scratch_hist"][1], label = "Scratch Val accur")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Accuracy Value")

        plt.subplot(223)
        plt.plot(dic["scratch_hist"][2], label = "Scratch Train loss")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Loss Value")


        plt.subplot(224)
        plt.plot(dic["scratch_hist"][3], label = "Scratch Val loss")
        plt.legend()
        plt.xlabel("Epochs")
        plt.ylabel("Loss Value")
    
    
    plt.savefig(figname)
    plt.show()

# %%
figname= f"test2_seed42.png"
eval_plot(dico, figname, scratch = True)

# %%
dico

# %%
#Save data
np.save("summary_Lenet_mnist.npy", dico)
